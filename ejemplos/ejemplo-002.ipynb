# %%
# Importación de paquetes requeridos
import warnings

import io
import requests
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
plt.close("all")
import scipy
import numpy as np

from IPython.display import display, Markdown, Latex

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import dateparser
import json

# %%
import matplotlib.pylab as pylab
params = {
    'legend.fontsize': 'x-large',
    'axes.labelsize': 'x-large',
    'axes.titlesize':'x-large',
    'xtick.labelsize':'x-large',
    'ytick.labelsize':'x-large',
    'lines.linewidth' : 3,
}
pylab.rcParams.update(params)

# %%
# Función auxiliar para visualizar los datos
def pp(obj):
    print(json.dumps(obj, indent=2))

# %%
# Parmámetros
iga_api_base_url = 'http://ing-acc-movil01/ingenier@/symfony/public/index.php/api'
site_names = ['A04-S001', 'A06-S001', 'A01-S001']
site_names_str = ', '.join(site_names)

# %%
display(Markdown(f"# Ejemplo 002: Descarga del reporte de Datos Outdoor para un conjunto de sitios en formato Excel"))
# Out:
# # Ejemplo 002: Descarga del reporte de Datos Outdoor para un conjunto de sitios en formato Excel

# %%
# Llamamos a un endpoint de prueba en la API de IGA para verificar conectividad
display(Markdown("### IGA API test"))
x = requests.get(iga_api_base_url + '/public/db-sync-state')
pp(x.json())
# Out:
# ### IGA API test
# {
#   "status": "success",
#   "data": {
#     "Uid": "41158",
#     "State": "DB_SYNC_STATE_IDLE",
#     "LastSyncTimestamp": "16-05-2022 16:24:17",
#     "SyncState": "OK",
#     "ProjectsUpdated": "DataManager, NORAN"
#   }
# }

# %%
# Llamamos al endpoint generic-report para obtener el reporte de datos outdoor del sitio seleccionado:

# Parámetros en el payload de la request con que llamamos al endpoint de IGA:
payload = {
    # Nombre del reporte: datos_outdoor
    "reportName": "datos_outdoor",
    # Sitios seleccionados: los códigos de sitio que están almacenados en la variable site_names
    "siteNames": site_names,
    # Parámetros de filtrado: ninguno (objeto vacío: {})
    "filteringParams": {},
    # Seleccionar por nombres de sitio: sí
    "selectBySiteNames": True,
    # Seleccionar por parámetros de filtrado: no
    "selectByFilteringParams": False
}
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)

# En x almacenamos los datos devueltos por el endpoint de IGA. Es un archivo xlsx en formato binario

# Usando pandas, con la función read_excel, leemos los datos y los almacenamos en memoria como un objeto de python:
with io.BytesIO(x.content) as fh:
    df = pd.read_excel(fh)

# %%
# Visualizamos los datos obtenidos:
display(Markdown(f"# Datos Outdoor - Sitios: {site_names_str}"))
display(Markdown(f"### Tabla con orientación normal:"))
display(df)

display(Markdown(f"### Tabla transpuesta:"))
# Los mismos datos pero transponiéndolos (intercambiando filas por columnas) para poder ver mejor todos los nombres de columnas:
display(df.transpose())
# Out:
# # Datos Outdoor - Sitios: A04-S001, A06-S001, A01-S001
# ### Tabla con orientación normal:
#    Proyecto    Código     Sector                   Portadora        Estado  \
# 0      MEDI  A01-S001  XDCAMPB11  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 1      MEDI  A01-S001  XDCAMPB12  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 2      MEDI  A01-S001  XDCAMPB13  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 3      MEDI  A01-S001  XDCAMPG11                     GSM1900  No Operativo
# 4      MEDI  A01-S001  XDCAMPG12                     GSM1900  No Operativo
# ..      ...       ...        ...                         ...           ...
# 91     LISU  A06-S001  XACHIPV12               WCDMA850_4358     Operativo
# 92     LISU  A06-S001  XACHIPV13               WCDMA850_4358     Operativo
# 93     LISU  A06-S001  XACHIPV21               WCDMA850_4379     Operativo
# 94     LISU  A06-S001  XACHIPV22               WCDMA850_4379     Operativo
# 95     LISU  A06-S001  XACHIPV23               WCDMA850_4379     Operativo
#
#     Latitud Antena  Longitud Antena  Id Antena    Modelo Antena  Id Puerto  \
# 0       -34.377472       -64.506528         19       ATR4518R13          3
# 1       -34.377472       -64.506528         20       ATR4518R13          3
# 2       -34.377472       -64.506528         21       ATR4518R13          3
# 3       -34.377472       -64.506528          1        ADU4517R3          3
# 4       -34.377472       -64.506528          2        ADU4517R3          3
# ..             ...              ...        ...              ...        ...
# 91      -30.960312       -62.338604          3  DBXLH-6565A-VTM          1
# 92      -30.960312       -62.338604          4  DBXLH-6565A-VTM          1
# 93      -30.960312       -62.338604          2  DBXLH-6565A-VTM          1
# 94      -30.960312       -62.338604          3  DBXLH-6565A-VTM          1
# 95      -30.960312       -62.338604          4  DBXLH-6565A-VTM          1
#
#     ... Altura Antena Azimuth Físico Azimuth Efectivo Tilt Mec.  Tilt Eléc.  \
# 0   ...          40.0           40.0             40.0      -0.0         2.0
# 1   ...          40.0          110.0            110.0      -0.0         2.0
# 2   ...          40.0          280.0            280.0      -0.0         2.0
# 3   ...          44.0           40.0             41.0      -0.0         5.0
# 4   ...          44.0          110.0            111.0      -0.0         3.0
# ..  ...           ...            ...              ...       ...         ...
# 91  ...          56.0          120.0            120.0      -0.0         1.0
# 92  ...          56.0          240.0            240.0      -0.0         1.0
# 93  ...          56.0            0.0              0.0      -0.0         1.0
# 94  ...          56.0          120.0            120.0      -0.0         1.0
# 95  ...          56.0          240.0            240.0      -0.0         1.0
#
#     Twist  Ancho Horiz.  Ancho Vert.  Ganancia dBi  Cota de Terreno
# 0     0.0            65           13     14.220000           230.69
# 1     0.0            65           13     14.220000           230.69
# 2     0.0            65           13     14.220000           230.69
# 3     0.0            64            6     16.826250           230.69
# 4     0.0            64            6     16.826250           230.69
# ..    ...           ...          ...           ...              ...
# 91    0.0            67           15     13.875438          -999.00
# 92    0.0            67           15     13.875438          -999.00
# 93    0.0            67           15     13.875438          -999.00
# 94    0.0            67           15     13.875438          -999.00
# 95    0.0            67           15     13.875438          -999.00
#
# [96 rows x 26 columns]
# ### Tabla transpuesta:
#                                              0                           1   \
# Proyecto                                   MEDI                        MEDI
# Código                                 A01-S001                    A01-S001
# Sector                                XDCAMPB11                   XDCAMPB12
# Portadora            LTE FDD_700MHz_9312_NB_IoT  LTE FDD_700MHz_9312_NB_IoT
# Estado                             No Operativo                No Operativo
# Latitud Antena                       -34.377472                  -34.377472
# Longitud Antena                      -64.506528                  -64.506528
# Id Antena                                    19                          20
# Modelo Antena                        ATR4518R13                  ATR4518R13
# Id Puerto                                     3                           3
# Id Puertos Uplink                           3,4                         3,4
# Id Puertos Downlink                         3,4                         3,4
# Config. Puertos                           2Rx2T                       2Rx2T
# Controlador Eléc            Port 3-4 690-960Mhz         Port 3-4 690-960Mhz
# Frec. Mín.                                  690                         690
# Frec. Máx.                                  960                         960
# Altura Antena                              40.0                        40.0
# Azimuth Físico                             40.0                       110.0
# Azimuth Efectivo                           40.0                       110.0
# Tilt Mec.                                  -0.0                        -0.0
# Tilt Eléc.                                  2.0                         2.0
# Twist                                       0.0                         0.0
# Ancho Horiz.                                 65                          65
# Ancho Vert.                                  13                          13
# Ganancia dBi                              14.22                       14.22
# Cota de Terreno                          230.69                      230.69
#
#                                              2                      3   \
# Proyecto                                   MEDI                   MEDI
# Código                                 A01-S001               A01-S001
# Sector                                XDCAMPB13              XDCAMPG11
# Portadora            LTE FDD_700MHz_9312_NB_IoT                GSM1900
# Estado                             No Operativo           No Operativo
# Latitud Antena                       -34.377472             -34.377472
# Longitud Antena                      -64.506528             -64.506528
# Id Antena                                    21                      1
# Modelo Antena                        ATR4518R13              ADU4517R3
# Id Puerto                                     3                      3
# Id Puertos Uplink                           3,4                    3,4
# Id Puertos Downlink                         3,4                    3,4
# Config. Puertos                           2Rx2T                  2Rx2T
# Controlador Eléc            Port 3-4 690-960Mhz  Port 3-4 1710-2180MHz
# Frec. Mín.                                  690                   1710
# Frec. Máx.                                  960                   2180
# Altura Antena                              40.0                   44.0
# Azimuth Físico                            280.0                   40.0
# Azimuth Efectivo                          280.0                   41.0
# Tilt Mec.                                  -0.0                   -0.0
# Tilt Eléc.                                  2.0                    5.0
# Twist                                       0.0                    0.0
# Ancho Horiz.                                 65                     64
# Ancho Vert.                                  13                      6
# Ganancia dBi                              14.22               16.82625
# Cota de Terreno                          230.69                 230.69
#
#                                         4                      5   \
# Proyecto                              MEDI                   MEDI
# Código                            A01-S001               A01-S001
# Sector                           XDCAMPG12              XDCAMPG13
# Portadora                          GSM1900                GSM1900
# Estado                        No Operativo           No Operativo
# Latitud Antena                  -34.377472             -34.377472
# Longitud Antena                 -64.506528             -64.506528
# Id Antena                                2                      3
# Modelo Antena                    ADU4517R3              ADU4517R3
# Id Puerto                                3                      3
# Id Puertos Uplink                      3,4                    3,4
# Id Puertos Downlink                    3,4                    3,4
# Config. Puertos                      2Rx2T                  2Rx2T
# Controlador Eléc     Port 3-4 1710-2180MHz  Port 3-4 1710-2180MHz
# Frec. Mín.                            1710                   1710
# Frec. Máx.                            2180                   2180
# Altura Antena                         44.0                   44.0
# Azimuth Físico                       110.0                  280.0
# Azimuth Efectivo                     111.0                  281.0
# Tilt Mec.                             -0.0                   -0.0
# Tilt Eléc.                             3.0                    2.0
# Twist                                  0.0                    0.0
# Ancho Horiz.                            64                     64
# Ancho Vert.                              6                      6
# Ganancia dBi                      16.82625               16.82625
# Cota de Terreno                     230.69                 230.69
#
#                                       6                    7   \
# Proyecto                            MEDI                 MEDI
# Código                          A01-S001             A01-S001
# Sector                         XDCAMPH11            XDCAMPH12
# Portadora                         GSM850               GSM850
# Estado                         Operativo            Operativo
# Latitud Antena                -34.377472           -34.377472
# Longitud Antena               -64.506528           -64.506528
# Id Antena                              1                    2
# Modelo Antena                  ADU4517R3            ADU4517R3
# Id Puerto                              1                    1
# Id Puertos Uplink                    1,2                  1,2
# Id Puertos Downlink                  1,2                  1,2
# Config. Puertos                    2Rx2T                2Rx2T
# Controlador Eléc     Port 1-2 790-960MHz  Port 1-2 790-960MHz
# Frec. Mín.                           790                  790
# Frec. Máx.                           960                  960
# Altura Antena                       44.0                 44.0
# Azimuth Físico                      40.0                110.0
# Azimuth Efectivo                    39.0                109.0
# Tilt Mec.                           -0.0                 -0.0
# Tilt Eléc.                           3.0                  1.0
# Twist                                0.0                  0.0
# Ancho Horiz.                          68                   68
# Ancho Vert.                           14                   14
# Ganancia dBi                   14.564095            14.564095
# Cota de Terreno                   230.69               230.69
#
#                                       8                      9   ...  \
# Proyecto                            MEDI                   MEDI  ...
# Código                          A01-S001               A01-S001  ...
# Sector                         XDCAMPH13              XDCAMPL11  ...
# Portadora                         GSM850       LTE FDD_AWS_2225  ...
# Estado                         Operativo              Operativo  ...
# Latitud Antena                -34.377472             -34.377472  ...
# Longitud Antena               -64.506528             -64.506528  ...
# Id Antena                              3                     19  ...
# Modelo Antena                  ADU4517R3             ATR4518R13  ...
# Id Puerto                              1                      1  ...
# Id Puertos Uplink                    1,2                1,2,5,6  ...
# Id Puertos Downlink                  1,2                    1,2  ...
# Config. Puertos                    2Rx2T                  4Rx2T  ...
# Controlador Eléc     Port 1-2 790-960MHz  Port 1-2 1710-2690Mhz  ...
# Frec. Mín.                           790                   1710  ...
# Frec. Máx.                           960                   2690  ...
# Altura Antena                       44.0                   40.0  ...
# Azimuth Físico                     280.0                   40.0  ...
# Azimuth Efectivo                   279.0                   41.0  ...
# Tilt Mec.                           -0.0                   -0.0  ...
# Tilt Eléc.                           0.0                    2.0  ...
# Twist                                0.0                    0.0  ...
# Ancho Horiz.                          68                     62  ...
# Ancho Vert.                           14                      6  ...
# Ganancia dBi                   14.564095                  18.17  ...
# Cota de Terreno                   230.69                 230.69  ...
#
#                                       86                    87  \
# Proyecto                            LISU                  LISU
# Código                          A06-S001              A06-S001
# Sector                         XACHIPN13             XACHIPO11
# Portadora            LTE FDD_700MHz_9360   LTE FDD_850MHz_2476
# Estado                         Operativo          No Operativo
# Latitud Antena                -30.960312            -30.960312
# Longitud Antena               -62.338604            -62.338604
# Id Antena                              7                     2
# Modelo Antena                 ATR4518R13       DBXLH-6565A-VTM
# Id Puerto                              3                     1
# Id Puertos Uplink                    3,4                   1,2
# Id Puertos Downlink                  3,4                   1,2
# Config. Puertos                    2Rx2T                 2Rx2T
# Controlador Eléc     Port 3-4 690-960Mhz  Port 1-2 806-960 MHz
# Frec. Mín.                           690                   806
# Frec. Máx.                           960                   960
# Altura Antena                       56.0                  56.0
# Azimuth Físico                     240.0                   0.0
# Azimuth Efectivo                   240.0                   0.0
# Tilt Mec.                            1.0                  -0.0
# Tilt Eléc.                           1.0                   1.0
# Twist                                0.0                   0.0
# Ancho Horiz.                          65                    67
# Ancho Vert.                           13                    15
# Ganancia dBi                       14.22             13.875438
# Cota de Terreno                   -999.0                -999.0
#
#                                        88                    89  \
# Proyecto                             LISU                  LISU
# Código                           A06-S001              A06-S001
# Sector                          XACHIPO12             XACHIPO13
# Portadora             LTE FDD_850MHz_2476   LTE FDD_850MHz_2476
# Estado                       No Operativo          No Operativo
# Latitud Antena                 -30.960312            -30.960312
# Longitud Antena                -62.338604            -62.338604
# Id Antena                               3                     4
# Modelo Antena             DBXLH-6565A-VTM       DBXLH-6565A-VTM
# Id Puerto                               1                     1
# Id Puertos Uplink                     1,2                   1,2
# Id Puertos Downlink                   1,2                   1,2
# Config. Puertos                     2Rx2T                 2Rx2T
# Controlador Eléc     Port 1-2 806-960 MHz  Port 1-2 806-960 MHz
# Frec. Mín.                            806                   806
# Frec. Máx.                            960                   960
# Altura Antena                        56.0                  56.0
# Azimuth Físico                      120.0                 240.0
# Azimuth Efectivo                    120.0                 240.0
# Tilt Mec.                            -0.0                  -0.0
# Tilt Eléc.                            1.0                   1.0
# Twist                                 0.0                   0.0
# Ancho Horiz.                           67                    67
# Ancho Vert.                            15                    15
# Ganancia dBi                    13.875438             13.875438
# Cota de Terreno                    -999.0                -999.0
#
#                                        90                    91  \
# Proyecto                             LISU                  LISU
# Código                           A06-S001              A06-S001
# Sector                          XACHIPV11             XACHIPV12
# Portadora                   WCDMA850_4358         WCDMA850_4358
# Estado                          Operativo             Operativo
# Latitud Antena                 -30.960312            -30.960312
# Longitud Antena                -62.338604            -62.338604
# Id Antena                               2                     3
# Modelo Antena             DBXLH-6565A-VTM       DBXLH-6565A-VTM
# Id Puerto                               1                     1
# Id Puertos Uplink                     1,2                   1,2
# Id Puertos Downlink                   1,2                   1,2
# Config. Puertos                     2Rx2T                 2Rx2T
# Controlador Eléc     Port 1-2 806-960 MHz  Port 1-2 806-960 MHz
# Frec. Mín.                            806                   806
# Frec. Máx.                            960                   960
# Altura Antena                        56.0                  56.0
# Azimuth Físico                        0.0                 120.0
# Azimuth Efectivo                      0.0                 120.0
# Tilt Mec.                            -0.0                  -0.0
# Tilt Eléc.                            1.0                   1.0
# Twist                                 0.0                   0.0
# Ancho Horiz.                           67                    67
# Ancho Vert.                            15                    15
# Ganancia dBi                    13.875438             13.875438
# Cota de Terreno                    -999.0                -999.0
#
#                                        92                    93  \
# Proyecto                             LISU                  LISU
# Código                           A06-S001              A06-S001
# Sector                          XACHIPV13             XACHIPV21
# Portadora                   WCDMA850_4358         WCDMA850_4379
# Estado                          Operativo             Operativo
# Latitud Antena                 -30.960312            -30.960312
# Longitud Antena                -62.338604            -62.338604
# Id Antena                               4                     2
# Modelo Antena             DBXLH-6565A-VTM       DBXLH-6565A-VTM
# Id Puerto                               1                     1
# Id Puertos Uplink                     1,2                   1,2
# Id Puertos Downlink                   1,2                   1,2
# Config. Puertos                     2Rx2T                 2Rx2T
# Controlador Eléc     Port 1-2 806-960 MHz  Port 1-2 806-960 MHz
# Frec. Mín.                            806                   806
# Frec. Máx.                            960                   960
# Altura Antena                        56.0                  56.0
# Azimuth Físico                      240.0                   0.0
# Azimuth Efectivo                    240.0                   0.0
# Tilt Mec.                            -0.0                  -0.0
# Tilt Eléc.                            1.0                   1.0
# Twist                                 0.0                   0.0
# Ancho Horiz.                           67                    67
# Ancho Vert.                            15                    15
# Ganancia dBi                    13.875438             13.875438
# Cota de Terreno                    -999.0                -999.0
#
#                                        94                    95
# Proyecto                             LISU                  LISU
# Código                           A06-S001              A06-S001
# Sector                          XACHIPV22             XACHIPV23
# Portadora                   WCDMA850_4379         WCDMA850_4379
# Estado                          Operativo             Operativo
# Latitud Antena                 -30.960312            -30.960312
# Longitud Antena                -62.338604            -62.338604
# Id Antena                               3                     4
# Modelo Antena             DBXLH-6565A-VTM       DBXLH-6565A-VTM
# Id Puerto                               1                     1
# Id Puertos Uplink                     1,2                   1,2
# Id Puertos Downlink                   1,2                   1,2
# Config. Puertos                     2Rx2T                 2Rx2T
# Controlador Eléc     Port 1-2 806-960 MHz  Port 1-2 806-960 MHz
# Frec. Mín.                            806                   806
# Frec. Máx.                            960                   960
# Altura Antena                        56.0                  56.0
# Azimuth Físico                      120.0                 240.0
# Azimuth Efectivo                    120.0                 240.0
# Tilt Mec.                            -0.0                  -0.0
# Tilt Eléc.                            1.0                   1.0
# Twist                                 0.0                   0.0
# Ancho Horiz.                           67                    67
# Ancho Vert.                            15                    15
# Ganancia dBi                    13.875438             13.875438
# Cota de Terreno                    -999.0                -999.0
#
# [26 rows x 96 columns]

# %%
# Aplicamos filtros
# Seleccionamos los datos únicamente del primer sitio
site_name = site_names[0]
display(Markdown(f"### Sitio seleccionado: {site_name}"))
df1 = df.loc[df['Código'] == site_name]
display(df1)
# Out:
# ### Sitio seleccionado: A04-S001
#    Proyecto    Código     Sector                   Portadora     Estado  \
# 33     LISU  A04-S001  BBARADB11  LTE FDD_700MHz_9312_NB_IoT  Operativo
# 34     LISU  A04-S001  BBARADB12  LTE FDD_700MHz_9312_NB_IoT  Operativo
# 35     LISU  A04-S001  BBARADB13  LTE FDD_700MHz_9312_NB_IoT  Operativo
# 36     LISU  A04-S001  BBARADF11        LTE FDD_2600MHz_3150  Operativo
# 37     LISU  A04-S001  BBARADF12        LTE FDD_2600MHz_3150  Operativo
# 38     LISU  A04-S001  BBARADF13        LTE FDD_2600MHz_3150  Operativo
# 39     LISU  A04-S001  BBARADG11                     GSM1900  Operativo
# 40     LISU  A04-S001  BBARADG12                     GSM1900  Operativo
# 41     LISU  A04-S001  BBARADG13                     GSM1900  Operativo
# 42     LISU  A04-S001  BBARADH11                      GSM850  Operativo
# 43     LISU  A04-S001  BBARADH12                      GSM850  Operativo
# 44     LISU  A04-S001  BBARADH13                      GSM850  Operativo
# 45     LISU  A04-S001  BBARADL11            LTE FDD_AWS_2225  Operativo
# 46     LISU  A04-S001  BBARADL12            LTE FDD_AWS_2225  Operativo
# 47     LISU  A04-S001  BBARADL13            LTE FDD_AWS_2225  Operativo
# 48     LISU  A04-S001  BBARADM11         LTE FDD_1900MHz_950  Operativo
# 49     LISU  A04-S001  BBARADM12         LTE FDD_1900MHz_950  Operativo
# 50     LISU  A04-S001  BBARADM13         LTE FDD_1900MHz_950  Operativo
# 51     LISU  A04-S001  BBARADM14         LTE FDD_1900MHz_950  Operativo
# 52     LISU  A04-S001  BBARADM15         LTE FDD_1900MHz_950  Operativo
# 53     LISU  A04-S001  BBARADM16         LTE FDD_1900MHz_950  Operativo
# 54     LISU  A04-S001  BBARADN11         LTE FDD_700MHz_9360  Operativo
# 55     LISU  A04-S001  BBARADN12         LTE FDD_700MHz_9360  Operativo
# 56     LISU  A04-S001  BBARADN13         LTE FDD_700MHz_9360  Operativo
# 57     LISU  A04-S001  BBARADV11               WCDMA850_4358  Operativo
# 58     LISU  A04-S001  BBARADV12               WCDMA850_4358  Operativo
# 59     LISU  A04-S001  BBARADV13               WCDMA850_4358  Operativo
# 60     LISU  A04-S001  BBARADV14               WCDMA850_4358  Operativo
# 61     LISU  A04-S001  BBARADV15               WCDMA850_4358  Operativo
# 62     LISU  A04-S001  BBARADV16               WCDMA850_4358  Operativo
# 63     LISU  A04-S001  BBARADV21               WCDMA850_4379  Operativo
# 64     LISU  A04-S001  BBARADV22               WCDMA850_4379  Operativo
# 65     LISU  A04-S001  BBARADV23               WCDMA850_4379  Operativo
# 66     LISU  A04-S001  BBARADV24               WCDMA850_4379  Operativo
# 67     LISU  A04-S001  BBARADV25               WCDMA850_4379  Operativo
# 68     LISU  A04-S001  BBARADV26               WCDMA850_4379  Operativo
#
#     Latitud Antena  Longitud Antena  Id Antena           Modelo Antena  \
# 33      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 34      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 35      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 36      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 37      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 38      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 39      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 40      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 41      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 42      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 43      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 44      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 45      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 46      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 47      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 48      -33.805919        -59.50455          7            2UNPX203.6R2
# 49      -33.805919        -59.50455          8            2UNPX203.6R2
# 50      -33.805919        -59.50455          9            2UNPX203.6R2
# 51      -33.805919        -59.50455          7            2UNPX203.6R2
# 52      -33.805919        -59.50455          8            2UNPX203.6R2
# 53      -33.805919        -59.50455          9            2UNPX203.6R2
# 54      -33.805919        -59.50455          4  ODI-065R15MM18JJJ02-GQ
# 55      -33.805919        -59.50455          5  ODI-065R15MM18JJJ02-GQ
# 56      -33.805919        -59.50455          6  ODI-065R15MM18JJJ02-GQ
# 57      -33.805919        -59.50455          7            2UNPX203.6R2
# 58      -33.805919        -59.50455          8            2UNPX203.6R2
# 59      -33.805919        -59.50455          9            2UNPX203.6R2
# 60      -33.805919        -59.50455          7            2UNPX203.6R2
# 61      -33.805919        -59.50455          8            2UNPX203.6R2
# 62      -33.805919        -59.50455          9            2UNPX203.6R2
# 63      -33.805919        -59.50455          7            2UNPX203.6R2
# 64      -33.805919        -59.50455          8            2UNPX203.6R2
# 65      -33.805919        -59.50455          9            2UNPX203.6R2
# 66      -33.805919        -59.50455          7            2UNPX203.6R2
# 67      -33.805919        -59.50455          8            2UNPX203.6R2
# 68      -33.805919        -59.50455          9            2UNPX203.6R2
#
#     Id Puerto  ... Altura Antena Azimuth Físico Azimuth Efectivo Tilt Mec.  \
# 33          9  ...          44.0          100.0            100.0       3.0
# 34          9  ...          44.0          220.0            220.0       2.0
# 35          9  ...          44.0          340.0            340.0       2.0
# 36          1  ...          44.0          100.0            100.0       3.0
# 37          1  ...          44.0          220.0            220.0       2.0
# 38          1  ...          44.0          340.0            340.0       2.0
# 39          1  ...          44.0          100.0            100.0       3.0
# 40          1  ...          44.0          220.0            220.0       2.0
# 41          1  ...          44.0          340.0            340.0       2.0
# 42          7  ...          44.0          100.0            102.0       3.0
# 43          7  ...          44.0          220.0            222.0       2.0
# 44          7  ...          44.0          340.0            342.0       2.0
# 45          1  ...          44.0          100.0            100.0       3.0
# 46          1  ...          44.0          220.0            220.0       2.0
# 47          1  ...          44.0          340.0            340.0       2.0
# 48          5  ...          38.0          100.0             69.0      -0.0
# 49          5  ...          38.0          220.0            189.0      -0.0
# 50          5  ...          38.0          340.0            309.0      -0.0
# 51          7  ...          38.0          100.0            132.0      -0.0
# 52          7  ...          38.0          220.0            252.0      -0.0
# 53          7  ...          38.0          340.0             12.0      -0.0
# 54          9  ...          44.0          100.0            100.0       3.0
# 55          9  ...          44.0          220.0            220.0       2.0
# 56          9  ...          44.0          340.0            340.0       2.0
# 57          1  ...          38.0          100.0             70.0      -0.0
# 58          1  ...          38.0          220.0            190.0      -0.0
# 59          1  ...          38.0          340.0            310.0      -0.0
# 60          3  ...          38.0          100.0            132.0      -0.0
# 61          3  ...          38.0          220.0            252.0      -0.0
# 62          3  ...          38.0          340.0             12.0      -0.0
# 63          1  ...          38.0          100.0             70.0      -0.0
# 64          1  ...          38.0          220.0            190.0      -0.0
# 65          1  ...          38.0          340.0            310.0      -0.0
# 66          3  ...          38.0          100.0            132.0      -0.0
# 67          3  ...          38.0          220.0            252.0      -0.0
# 68          3  ...          38.0          340.0             12.0      -0.0
#
#     Tilt Eléc.  Twist  Ancho Horiz.  Ancho Vert.  Ganancia dBi  \
# 33         6.0    0.0            58           14     14.404444
# 34         6.0    0.0            58           14     14.404444
# 35         5.0    0.0            58           14     14.404444
# 36         2.0    0.0            60            6     17.281273
# 37         5.0    0.0            60            6     17.281273
# 38         5.0    0.0            60            6     17.281273
# 39         2.0    0.0            60            6     17.281273
# 40         5.0    0.0            60            6     17.281273
# 41         5.0    0.0            60            6     17.281273
# 42         6.0    0.0            56           14     14.376444
# 43         6.0    0.0            56           14     14.376444
# 44         5.0    0.0            56           14     14.376444
# 45         2.0    0.0            60            6     17.281273
# 46         5.0    0.0            60            6     17.281273
# 47         5.0    0.0            60            6     17.281273
# 48         2.0    0.0            42           11     15.906667
# 49         6.0    0.0            42           11     15.906667
# 50         5.0    0.0            42           11     15.906667
# 51         2.0    0.0            41           12     15.924848
# 52         6.0    0.0            41           12     15.924848
# 53         5.0    0.0            41           12     15.924848
# 54         6.0    0.0            58           14     14.404444
# 55         6.0    0.0            58           14     14.404444
# 56         5.0    0.0            58           14     14.404444
# 57         3.0    0.0            41           24     13.427500
# 58         3.0    0.0            41           24     13.427500
# 59         8.0    0.0            41           24     13.427500
# 60         3.0    0.0            42           24     13.436875
# 61         4.0    0.0            42           24     13.436875
# 62         6.0    0.0            42           24     13.436875
# 63         3.0    0.0            41           24     13.427500
# 64         3.0    0.0            41           24     13.427500
# 65         8.0    0.0            41           24     13.427500
# 66         3.0    0.0            42           24     13.436875
# 67         4.0    0.0            42           24     13.436875
# 68         6.0    0.0            42           24     13.436875
#
#     Cota de Terreno
# 33            29.32
# 34            29.32
# 35            29.32
# 36            29.32
# 37            29.32
# 38            29.32
# 39            29.32
# 40            29.32
# 41            29.32
# 42            29.32
# 43            29.32
# 44            29.32
# 45            29.32
# 46            29.32
# 47            29.32
# 48            29.00
# 49            29.00
# 50            29.00
# 51            29.00
# 52            29.00
# 53            29.00
# 54            29.32
# 55            29.32
# 56            29.32
# 57            29.00
# 58            29.00
# 59            29.00
# 60            29.00
# 61            29.00
# 62            29.00
# 63            29.00
# 64            29.00
# 65            29.00
# 66            29.00
# 67            29.00
# 68            29.00
#
# [36 rows x 26 columns]

# %%
# Aplicamos un nuevo filtro para seleccionar únicamente las celdas de una portadora:
portadora = 'WCDMA850_4379'
display(Markdown(f"### Sitio seleccionado: {site_name}, portadora seleccionada: {portadora}"))
df2 = df1.loc[df1['Portadora'] == portadora]
display(df2)

# Los mismos datos, pero ordenando por nombre de celda en orden inverso
display(Markdown(f"### Sitio seleccionado: {site_name}, portadora seleccionada: {portadora}, ordenado por nombre de celda (desc)"))
display(df2.sort_values(by='Sector', ascending=False))
# Out:
# ### Sitio seleccionado: A04-S001, portadora seleccionada: WCDMA850_4379
#    Proyecto    Código     Sector      Portadora     Estado  Latitud Antena  \
# 63     LISU  A04-S001  BBARADV21  WCDMA850_4379  Operativo      -33.805919
# 64     LISU  A04-S001  BBARADV22  WCDMA850_4379  Operativo      -33.805919
# 65     LISU  A04-S001  BBARADV23  WCDMA850_4379  Operativo      -33.805919
# 66     LISU  A04-S001  BBARADV24  WCDMA850_4379  Operativo      -33.805919
# 67     LISU  A04-S001  BBARADV25  WCDMA850_4379  Operativo      -33.805919
# 68     LISU  A04-S001  BBARADV26  WCDMA850_4379  Operativo      -33.805919
#
#     Longitud Antena  Id Antena Modelo Antena  Id Puerto  ... Altura Antena  \
# 63        -59.50455          7  2UNPX203.6R2          1  ...          38.0
# 64        -59.50455          8  2UNPX203.6R2          1  ...          38.0
# 65        -59.50455          9  2UNPX203.6R2          1  ...          38.0
# 66        -59.50455          7  2UNPX203.6R2          3  ...          38.0
# 67        -59.50455          8  2UNPX203.6R2          3  ...          38.0
# 68        -59.50455          9  2UNPX203.6R2          3  ...          38.0
#
#    Azimuth Físico Azimuth Efectivo Tilt Mec.  Tilt Eléc.  Twist  Ancho Horiz.  \
# 63          100.0             70.0      -0.0         3.0    0.0            41
# 64          220.0            190.0      -0.0         3.0    0.0            41
# 65          340.0            310.0      -0.0         8.0    0.0            41
# 66          100.0            132.0      -0.0         3.0    0.0            42
# 67          220.0            252.0      -0.0         4.0    0.0            42
# 68          340.0             12.0      -0.0         6.0    0.0            42
#
#     Ancho Vert.  Ganancia dBi  Cota de Terreno
# 63           24     13.427500             29.0
# 64           24     13.427500             29.0
# 65           24     13.427500             29.0
# 66           24     13.436875             29.0
# 67           24     13.436875             29.0
# 68           24     13.436875             29.0
#
# [6 rows x 26 columns]
# ### Sitio seleccionado: A04-S001, portadora seleccionada: WCDMA850_4379, ordenado por nombre de celda (desc)
#    Proyecto    Código     Sector      Portadora     Estado  Latitud Antena  \
# 68     LISU  A04-S001  BBARADV26  WCDMA850_4379  Operativo      -33.805919
# 67     LISU  A04-S001  BBARADV25  WCDMA850_4379  Operativo      -33.805919
# 66     LISU  A04-S001  BBARADV24  WCDMA850_4379  Operativo      -33.805919
# 65     LISU  A04-S001  BBARADV23  WCDMA850_4379  Operativo      -33.805919
# 64     LISU  A04-S001  BBARADV22  WCDMA850_4379  Operativo      -33.805919
# 63     LISU  A04-S001  BBARADV21  WCDMA850_4379  Operativo      -33.805919
#
#     Longitud Antena  Id Antena Modelo Antena  Id Puerto  ... Altura Antena  \
# 68        -59.50455          9  2UNPX203.6R2          3  ...          38.0
# 67        -59.50455          8  2UNPX203.6R2          3  ...          38.0
# 66        -59.50455          7  2UNPX203.6R2          3  ...          38.0
# 65        -59.50455          9  2UNPX203.6R2          1  ...          38.0
# 64        -59.50455          8  2UNPX203.6R2          1  ...          38.0
# 63        -59.50455          7  2UNPX203.6R2          1  ...          38.0
#
#    Azimuth Físico Azimuth Efectivo Tilt Mec.  Tilt Eléc.  Twist  Ancho Horiz.  \
# 68          340.0             12.0      -0.0         6.0    0.0            42
# 67          220.0            252.0      -0.0         4.0    0.0            42
# 66          100.0            132.0      -0.0         3.0    0.0            42
# 65          340.0            310.0      -0.0         8.0    0.0            41
# 64          220.0            190.0      -0.0         3.0    0.0            41
# 63          100.0             70.0      -0.0         3.0    0.0            41
#
#     Ancho Vert.  Ganancia dBi  Cota de Terreno
# 68           24     13.436875             29.0
# 67           24     13.436875             29.0
# 66           24     13.436875             29.0
# 65           24     13.427500             29.0
# 64           24     13.427500             29.0
# 63           24     13.427500             29.0
#
# [6 rows x 26 columns]

# %%
# Trabajando con los datos así filtrados, queremos obtener, de la columna Tilt Eléc los valores mínimo, máximo y promedio:
df_tilt_elec = df2['Tilt Eléc.']
pp(list(df_tilt_elec))
# Mínimo
tilt_elec_min = min(df_tilt_elec)
# Máximo
tilt_elec_max = max(df_tilt_elec)
# Promedio
tilt_elec_avg = sum(df_tilt_elec) / len(df_tilt_elec)

display(Markdown(f"#### Tilt Eléc. Mín: {tilt_elec_min}"))
display(Markdown(f"#### Tilt Eléc. Máx: {tilt_elec_max}"))
display(Markdown(f"#### Tilt Eléc. Avg: {tilt_elec_avg}"))
# Out:
# [
#   3.0,
#   3.0,
#   8.0,
#   3.0,
#   4.0,
#   6.0
# ]
# #### Tilt Eléc. Mín: 3.0
# #### Tilt Eléc. Máx: 8.0
# #### Tilt Eléc. Avg: 4.5
