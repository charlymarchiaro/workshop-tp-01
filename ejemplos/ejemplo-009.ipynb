# %% [markdown]
# # Ejemplo 009
#
# **Problema:** Queremos obtener, para todos los sitios de la red:
# - Código de sitio
# - EMG
# - Nombre de sitio
# - Latitud
# - Longitud
# - SiteStatus
# - StationType
# - Región
# - Lista de eNODEB-ID
# - Lista de gNODEB-ID
# - RSH TP-Anf/Hue
# - RSH MOCN/MORAN

# %% [markdown]
# #### Importamos paquetes necesarios

# %%
# Importación de paquetes requeridos
import os
import io
import requests
import pandas as pd
import numpy as np

from IPython.display import display, Markdown, Latex

import json

# %% [markdown]
# #### Funciones auxiliares

# %%
# Función auxiliar para visualizar los datos
def pp(obj):
    print(json.dumps(obj, indent=2))

# %%
# La operación queda con la forma siguiente:
# «para cada fila r, convertir el valor de la columna "col" en un tipo numérico (pd.to_numeric),
# ignorando los valores nulos (errors='coerce'), redondeando hacia abajo al entero más cercano
# (np.floor) y almacenándolo como entero de 64 bits (astype('Int64'))»

def pd_to_int(df: pd.DataFrame, col: str) -> int:
    return np.floor(pd.to_numeric(df[col], errors='coerce')).astype('Int64')

# %% [markdown]
# #### Parámetros del script

# %%
# Parmámetros
iga_api_base_url = 'http://ing-acc-movil01.personal.corp/ingenier@/symfony/public/index.php/api'

# %% [markdown]
# #### Test de conectividad

# %%
# Llamamos a un endpoint de prueba en la API de IGA para verificar conectividad
x = requests.get(iga_api_base_url + '/public/db-sync-state')
pp(x.json())
# Out:
# {
#   "status": "success",
#   "data": {
#     "Uid": "82635",
#     "State": "DB_SYNC_STATE_UPDATING",
#     "LastSyncTimestamp": "14-09-2024 15:35:14",
#     "SyncState": "OK",
#     "ProjectsUpdated": "DataManager, AMBA, Litoral Sur"
#   }
# }

# %% [markdown]
# #### Descarga de reportes
#
# - Debemos descargar tres reportes: Datos Generales de Sitio, Datos de Integración, (RAN Sharing) - Datos generales.
# - Nos interesa obtener datos para todos los sitios de la red
# - El endpoint usado es /public/report/generic-report en los tres casos.
# - Los datos devueltos están en formato binario, y pueden ser leídos directamente por Pandas como un archivo .xlsx, y convertidos a un objeto DataFrame

# %%
# Parámetros en el payload de la request con que llamamos al endpoint de IGA:
payload = {
    # Nombre del reporte (lo completamos después)
    "reportName": None,
    # Sitios seleccionados: ninguno
    "siteNames": [],
    # Parámetros de filtrado: todos los sitios de la red (filtro vacío)
    "filteringParams": {},
    # Seleccionar por nombres de sitio: no
    "selectBySiteNames": False,
    # Seleccionar por parámetros de filtrado: sí
    "selectByFilteringParams": True
}

# Datos de Integración
payload["reportName"] = "datos_integracion"
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)
# En x almacenamos los datos devueltos por el endpoint de IGA.
# Es un archivo xlsx en formato binario

# Usando pandas, con la función read_excel, leemos los datos y los almacenamos
# en memoria como un objeto DataFrame:
with io.BytesIO(x.content) as fh:
    df_integracion_4g_raw = pd.read_excel(fh, "LTE")
    df_integracion_5g_raw = pd.read_excel(fh, "NR")

# Repetimos para los demás reportes:
payload["reportName"] = "datos_generales_sitio"
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)
with io.BytesIO(x.content) as fh:
    df_datos_generales_sitio_raw = pd.read_excel(fh, "Datos generales de sitio")
    
payload["reportName"] = "rsh_datos_generales"
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)
with io.BytesIO(x.content) as fh:
    df_rsh_datos_generales_raw = pd.read_excel(fh, "Datos generales")


display(df_datos_generales_sitio_raw)
display(df_integracion_4g_raw)
display(df_integracion_5g_raw)
display(df_rsh_datos_generales_raw)
# Out:
#            Código     EMG                            Nombre Tipo Estación  \
# 0        1_UNAGRO     NaN                         El Palmar         Macro
# 1        2_UNAGRO     NaN                         El Palmar         Macro
# 2        A01-E133  XRCESE                Río IV E Sarmiento         EasyM
# 3        A01-E134  XRCEAL                    Río IV LN Alem         EasyM
# 4        A01-E135  XRCEMO                  Río IV E Mosconi         EasyM
# ...           ...     ...                               ...           ...
# 19750      SPU996  XXYYZZ       AMBA BERAZATEGUI 2020 - 018         Macro
# 19751      SPU997  XXYYZZ       AMBA BERAZATEGUI 2020 - 019         Macro
# 19752      SPU998  SBB12O  Berazategui Barrio 12 de Octubre         Macro
# 19753      SPU999  XXYYZZ       AMBA BERAZATEGUI 2020 - 021         Macro
# 19754  Yacht Club  XXYYZZ                          Nordelta         Macro
#
#       Estado Sitio    Latitud   Longitud Región     Provincia   Departamento  \
# 0               CT -27.166490 -61.690980   LINO         Chaco  12 de Octubre
# 1               CT -27.199777 -61.845519   LINO         Chaco  12 de Octubre
# 2               OA -33.142181 -64.348739   MEDI       Córdoba     Río Cuarto
# 3               OA -33.141588 -64.338766   MEDI       Córdoba     Río Cuarto
# 4               OA -33.149821 -64.354526   MEDI       Córdoba     Río Cuarto
# ...            ...        ...        ...    ...           ...            ...
# 19750           BS -34.777053 -58.259333   AMBA  Buenos Aires    Berazategui
# 19751           BS -34.766352 -58.238844   AMBA  Buenos Aires    Berazategui
# 19752           BS -34.767692 -58.229362  AMBA   Buenos Aires    Berazategui
# 19753           BS -34.760799 -58.222894   AMBA  Buenos Aires    Berazategui
# 19754           BS -34.385084 -58.642913   AMBA  Buenos Aires          Tigre
#
#        ... Búsq. Altura Búsq. Radio Altura Estruc.     Propiet. Cota 0  \
# 0      ...         58.0      1000.0           60.0  Mástil con riendas
# 1      ...         58.0      1000.0           60.0  Mástil con riendas
# 2      ...         12.0        50.0            NaN                 NaN
# 3      ...         12.0        50.0            NaN                 NaN
# 4      ...         12.0        50.0            NaN                 NaN
# ...    ...          ...         ...            ...                 ...
# 19750  ...         20.0       100.0           20.0                 NaN
# 19751  ...         20.0       100.0           20.0                 NaN
# 19752  ...         20.0       100.0           25.0                 NaN
# 19753  ...         20.0       100.0           20.0                 NaN
# 19754  ...          NaN         NaN           40.0            Personal
#
#       Propiet. Estruc.                      Tipo Estruc. Plan de Obra  \
# 0      TECO - Personal   Mástil con riendas convencional          NaN
# 1      TECO - Personal   Mástil con riendas convencional          NaN
# 2                  NaN       Poste (con o sin luminaria)          NaN
# 3                  NaN       Poste (con o sin luminaria)          NaN
# 4                  NaN       Poste (con o sin luminaria)          NaN
# ...                ...                               ...          ...
# 19750                0                               NaN          NaN
# 19751                0                               NaN          NaN
# 19752              NaN                               NaN          NaN
# 19753                0                               NaN          NaN
# 19754         Personal  Torre autosoportada convencional          NaN
#
#       Proyecto            Clutter Clase Sitio
# 0         LINO             Barren           C
# 1         LINO  Grass-Agriculture           C
# 2         MEDI             Barren           D
# 3         MEDI           Suburban           D
# 4         MEDI           Suburban           D
# ...        ...                ...         ...
# 19750     AMBA           Suburban           C
# 19751     AMBA           Suburban           C
# 19752     AMBA           Suburban           C
# 19753     AMBA           Suburban           C
# 19754     AMBA  Grass-Agriculture           C
#
# [19755 rows x 34 columns]
#        Proyecto      Código     Sector                   Portadora  \
# 0          LINO    1_UNAGRO  HELPLMB11  LTE FDD_700MHz_9312_NB_IoT
# 1          LINO    1_UNAGRO  HELPLMB12  LTE FDD_700MHz_9312_NB_IoT
# 2          LINO    1_UNAGRO  HELPLMB13  LTE FDD_700MHz_9312_NB_IoT
# 3          LINO    1_UNAGRO  HELPLMN11         LTE FDD_700MHz_9360
# 4          LINO    1_UNAGRO  HELPLMN12         LTE FDD_700MHz_9360
# ...         ...         ...        ...                         ...
# 178110     AMBA  Yacht Club  NDELTPN12         LTE FDD_700MHz_9360
# 178111     AMBA  Yacht Club  NDELTPN13         LTE FDD_700MHz_9360
# 178112     AMBA  Yacht Club  NDELTPO11         LTE FDD_850MHz_2450
# 178113     AMBA  Yacht Club  NDELTPO12         LTE FDD_850MHz_2450
# 178114     AMBA  Yacht Club  NDELTPO13         LTE FDD_850MHz_2450
#
#                               MME      CGI        Estado  Vendor  E-NODEB Id  \
# 0       MME[1_2CLI-1_2BEL-1_2MUN]  722-34-           NaN   NOKIA         NaN
# 1       MME[1_2CLI-1_2BEL-1_2MUN]  722-34-           NaN   NOKIA         NaN
# 2       MME[1_2CLI-1_2BEL-1_2MUN]  722-34-           NaN   NOKIA         NaN
# 3       MME[1_2CLI-1_2BEL-1_2MUN]  722-34-           NaN   NOKIA         NaN
# 4       MME[1_2CLI-1_2BEL-1_2MUN]  722-34-           NaN   NOKIA         NaN
# ...                           ...      ...           ...     ...         ...
# 178110  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-  No Operativo  Huawei         NaN
# 178111  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-  No Operativo  Huawei         NaN
# 178112  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-  No Operativo  Huawei         NaN
# 178113  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-  No Operativo  Huawei         NaN
# 178114  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-  No Operativo  Huawei         NaN
#
#           TAC  Physical Cell Id  Logical Cell Id  RACH Root Seq.  \
# 0       31696                -1              NaN             NaN
# 1       31696                -1              NaN             NaN
# 2       31696                -1              NaN             NaN
# 3       11696                -1              NaN           638.0
# 4       11696                -1              NaN           500.0
# ...       ...               ...              ...             ...
# 178110  15102               160              NaN           310.0
# 178111  15102               161              NaN           330.0
# 178112  15102               162              NaN           300.0
# 178113  15102               160              NaN           310.0
# 178114  15102               161              NaN           330.0
#
#         PA Power dBm  Ref. Signal Boosting dB  EARFCN DL  EARFCN UL  PRACH CS  \
# 0               38.0                     3.00     9312.0    27312.0       NaN
# 1               38.0                     3.00     9312.0    27312.0       NaN
# 2               38.0                     3.00     9312.0    27312.0       NaN
# 3               46.0                     0.00     9360.0    27360.0      14.0
# 4               46.0                     0.00     9360.0    27360.0      14.0
# ...              ...                      ...        ...        ...       ...
# 178110          48.4                     1.77     9360.0    27360.0      12.0
# 178111          48.4                     1.77     9360.0    27360.0      12.0
# 178112          48.4                     1.77     2450.0    20450.0      12.0
# 178113          48.4                     1.77     2450.0    20450.0      12.0
# 178114          48.4                     1.77     2450.0    20450.0      12.0
#
#         Base Station Type  E-UTRAN Cell Id
# 0       FlexiSystemModule              NaN
# 1       FlexiSystemModule              NaN
# 2       FlexiSystemModule              NaN
# 3       FlexiSystemModule              NaN
# 4       FlexiSystemModule              NaN
# ...                   ...              ...
# 178110           BBU 3900              NaN
# 178111           BBU 3900              NaN
# 178112           BBU 3900              NaN
# 178113           BBU 3900              NaN
# 178114           BBU 3900              NaN
#
# [178115 rows x 20 columns]
#      Proyecto    Código     Sector           Portadora  \
# 0        MEDI  A01-S006  XLCARLR11   NR_Band_n7_534000
# 1        MEDI  A01-S006  XLCARLR12   NR_Band_n7_534000
# 2        MEDI  A01-S006  XLCARLR13   NR_Band_n7_534000
# 3        MEDI  A01-S018  XMAKENR11   NR_Band_n7_534000
# 4        MEDI  A01-S018  XMAKENR12   NR_Band_n7_534000
# ...       ...       ...        ...                 ...
# 3890     AMBA    SPU674  SPPMTPR12   NR_Band_n7_534000
# 3891     AMBA    SPU674  SPPMTPR13   NR_Band_n7_534000
# 3892     AMBA    SPU816  SCPESES11  NR_Band_n78_630000
# 3893     AMBA    SPU816  SCPESES12  NR_Band_n78_630000
# 3894     AMBA    SPU816  SCPESES13  NR_Band_n78_630000
#
#                             MME                 CGI        Estado  Vendor  \
# 0     MME[1_2CLI-1_2BEL-1_2MUN]  722-34-32931938304  No Operativo  HUAWEI
# 1     MME[1_2CLI-1_2BEL-1_2MUN]  722-34-32931938305  No Operativo  HUAWEI
# 2     MME[1_2CLI-1_2BEL-1_2MUN]  722-34-32931938306  No Operativo  HUAWEI
# 3     MME[1_2CLI-1_2BEL-1_2MUN]  722-34-32932134912  No Operativo  HUAWEI
# 4     MME[1_2CLI-1_2BEL-1_2MUN]  722-34-32932134913  No Operativo  HUAWEI
# ...                         ...                 ...           ...     ...
# 3890  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-41020194817  No Operativo  Huawei
# 3891  MME[1_2CLI-1_2BEL-1_2MUN]  722-34-41020194818  No Operativo  Huawei
# 3892                        NaN             722-34-  No Operativo     NaN
# 3893                        NaN             722-34-  No Operativo     NaN
# 3894                        NaN             722-34-  No Operativo     NaN
#
#       G-NODEB Id    TAC  Physical Cell Id  Logical Cell Id  RACH Root Seq.  \
# 0      2010006.0  10192               357              0.0               6
# 1      2010006.0  10192               360              1.0              12
# 2      2010006.0  10192               363              2.0              18
# 3      2010018.0  10192                 9              0.0               6
# 4      2010018.0  10192                12              1.0              12
# ...          ...    ...               ...              ...             ...
# 3890   2503674.0  15118               478              1.0              54
# 3891   2503674.0  15118               479              2.0              66
# 3892         NaN  15117                -1            350.0              44
# 3893         NaN  15117                -1            351.0               0
# 3894         NaN  15117                -1            352.0              22
#
#       PA Power dBm  EARFCN DL Base Station Type    NR Cell Id
# 0             50.0     534000          BBU 3900  3.293194e+10
# 1             50.0     534000          BBU 3900  3.293194e+10
# 2             50.0     534000          BBU 3900  3.293194e+10
# 3             50.0     534000          BBU 3900  3.293213e+10
# 4             50.0     534000          BBU 3900  3.293213e+10
# ...            ...        ...               ...           ...
# 3890          50.0     534000          BBU 5900  4.102019e+10
# 3891          50.0     534000          BBU 5900  4.102019e+10
# 3892          50.0     630000          BBU 5900           NaN
# 3893          50.0     630000          BBU 5900           NaN
# 3894          50.0     630000          BBU 5900           NaN
#
# [3895 rows x 17 columns]
#      Código Sitio (TP) Tipo Estación Estado Sitio    Latitud   Longitud  \
# 0             A01-S002         Macro           OA -34.722105 -63.505801
# 1             A01-S002         Macro           OA -34.722105 -63.505801
# 2             A01-S002         Macro           OA -34.722105 -63.505801
# 3             A01-S003         Macro           OA -34.517722 -63.946917
# 4             A01-S003         Macro           OA -34.517722 -63.946917
# ...                ...           ...          ...        ...        ...
# 4951           SPU2280         Macro           CT -34.737090 -58.330140
# 4952           SPU2280         Macro           CT -34.737090 -58.330140
# 4953           SPU2280         Macro           CT -34.737090 -58.330140
# 4954           SPU2280         Macro           CT -34.737090 -58.330140
# 4955           SPU2280         Macro           CT -34.737090 -58.330140
#
#      Nombre Celda (TP)            Portadora Modalidad RSH MOCN/MORAN  \
# 0            XHBOUCN11  LTE FDD_700MHz_9360  TP Anfitrión       MOCN
# 1            XHBOUCN12  LTE FDD_700MHz_9360  TP Anfitrión       MOCN
# 2            XHBOUCN13  LTE FDD_700MHz_9360  TP Anfitrión       MOCN
# 3            XSMAGDN11  LTE FDD_700MHz_9360  TP Anfitrión       MOCN
# 4            XSMAGDN12  LTE FDD_700MHz_9360  TP Anfitrión       MOCN
# ...                ...                  ...           ...        ...
# 4951         SQURSHL12     LTE FDD_AWS_2225    TP Huésped      MORAN
# 4952         SQURSHL13     LTE FDD_AWS_2225    TP Huésped      MORAN
# 4953         SQURSHN11  LTE FDD_700MHz_9360    TP Huésped      MORAN
# 4954         SQURSHN12  LTE FDD_700MHz_9360    TP Huésped      MORAN
# 4955         SQURSHN13  LTE FDD_700MHz_9360    TP Huésped      MORAN
#
#       Sector ID  Operador Código Sitio (Oper) Nodo (Oper) Nombre Celda (Oper)  \
# 0             1  Movistar               XS145      MXS145             MXS145A
# 1             2  Movistar               XS145      MXS145             MXS145B
# 2             3  Movistar               XS145      MXS145             MXS145C
# 3             1  Movistar               XS116      MXS116             MXS116A
# 4             2  Movistar               XS116      MXS116             MXS116B
# ...         ...       ...                 ...         ...                 ...
# 4951          2  Movistar               KSM03      LKSM03             LKSM03B
# 4952          3  Movistar               KSM03      LKSM03             LKSM03C
# 4953          1  Movistar               KSM03      MKSM03             MKSM03A
# 4954          2  Movistar               KSM03      MKSM03             MKSM03B
# 4955          3  Movistar               KSM03      MKSM03             MKSM03C
#
#      Banda             Notas                                 Proyecto RSH  \
# 0      B28               NaN                                      Etapa 5
# 1      B28               NaN                                      Etapa 5
# 2      B28               NaN                                      Etapa 5
# 3      B28               NaN                                      Etapa 4
# 4      B28               NaN                                      Etapa 4
# ...    ...               ...                                          ...
# 4951    B4  CSFB pedido a 3G  Centros de Emergencia - Hospitales COVID-19
# 4952    B4  CSFB pedido a 3G  Centros de Emergencia - Hospitales COVID-19
# 4953   B28  CSFB pedido a 3G  Centros de Emergencia - Hospitales COVID-19
# 4954   B28  CSFB pedido a 3G  Centros de Emergencia - Hospitales COVID-19
# 4955   B28  CSFB pedido a 3G  Centros de Emergencia - Hospitales COVID-19
#
#      Vendor 2G Vendor 3G Vendor 4G
# 0            H         H         H
# 1            H         H         H
# 2            H         H         H
# 3            H         H         H
# 4            H         H         H
# ...        ...       ...       ...
# 4951       NaN       NaN       NaN
# 4952       NaN       NaN       NaN
# 4953       NaN       NaN       NaN
# 4954       NaN       NaN       NaN
# 4955       NaN       NaN       NaN
#
# [4956 rows x 20 columns]

# %% [markdown]
# #### Procesamiento de los datos
#
# - De los datos de Integración, obtenemos para cada sitio los E-NODEB Ids y G-NODEB Ids
# - De los datos de RSH, obtenemos para cada sitio las modalidades de RSH y MOCN/MORAN
# - Unimos las tres tablas usando el campo Código de sitio

# %%
df_1 = (
    df_datos_generales_sitio_raw
    [['Código', 'EMG', 'Nombre', 'Tipo Estación', 'Estado Sitio', 'Latitud', 'Longitud', 'Región']]
).set_index('Código')
display(df_1)

df_2 = (
    df_integracion_4g_raw[df_integracion_4g_raw['E-NODEB Id'].notnull()]
    [['Código', 'E-NODEB Id']]
).drop_duplicates().groupby('Código')['E-NODEB Id'].apply(list).reset_index().set_index('Código')
display(df_2)

df_3 = (
    df_integracion_5g_raw[df_integracion_5g_raw['G-NODEB Id'].notnull()]
    [['Código', 'G-NODEB Id']]
).drop_duplicates().groupby('Código')['G-NODEB Id'].apply(list).reset_index().set_index('Código')
display(df_3)

df_4 = (
    df_rsh_datos_generales_raw
    [['Código Sitio (TP)', 'Modalidad RSH']]
).drop_duplicates().groupby('Código Sitio (TP)')['Modalidad RSH'].apply(list).reset_index().set_index('Código Sitio (TP)')
display(df_4)

df_5 = (
    df_rsh_datos_generales_raw
    [['Código Sitio (TP)', 'MOCN/MORAN']]
).drop_duplicates().groupby('Código Sitio (TP)')['MOCN/MORAN'].apply(list).reset_index().set_index('Código Sitio (TP)')
display(df_5)
# Out:
#                EMG                            Nombre Tipo Estación  \
# Código
# 1_UNAGRO       NaN                         El Palmar         Macro
# 2_UNAGRO       NaN                         El Palmar         Macro
# A01-E133    XRCESE                Río IV E Sarmiento         EasyM
# A01-E134    XRCEAL                    Río IV LN Alem         EasyM
# A01-E135    XRCEMO                  Río IV E Mosconi         EasyM
# ...            ...                               ...           ...
# SPU996      XXYYZZ       AMBA BERAZATEGUI 2020 - 018         Macro
# SPU997      XXYYZZ       AMBA BERAZATEGUI 2020 - 019         Macro
# SPU998      SBB12O  Berazategui Barrio 12 de Octubre         Macro
# SPU999      XXYYZZ       AMBA BERAZATEGUI 2020 - 021         Macro
# Yacht Club  XXYYZZ                          Nordelta         Macro
#
#            Estado Sitio    Latitud   Longitud Región
# Código
# 1_UNAGRO             CT -27.166490 -61.690980   LINO
# 2_UNAGRO             CT -27.199777 -61.845519   LINO
# A01-E133             OA -33.142181 -64.348739   MEDI
# A01-E134             OA -33.141588 -64.338766   MEDI
# A01-E135             OA -33.149821 -64.354526   MEDI
# ...                 ...        ...        ...    ...
# SPU996               BS -34.777053 -58.259333   AMBA
# SPU997               BS -34.766352 -58.238844   AMBA
# SPU998               BS -34.767692 -58.229362  AMBA
# SPU999               BS -34.760799 -58.222894   AMBA
# Yacht Club           BS -34.385084 -58.642913   AMBA
#
# [19755 rows x 7 columns]
#           E-NODEB Id
# Código
# A01-E133   [10133.0]
# A01-E134   [10133.0]
# A01-E135   [10133.0]
# A01-E136   [10133.0]
# A01-E138   [10138.0]
# ...              ...
# SPU995    [503995.0]
# SPU996    [503996.0]
# SPU997    [503997.0]
# SPU998    [503998.0]
# SPU999    [503999.0]
#
# [12275 rows x 1 columns]
#            G-NODEB Id
# Código
# A01-S006  [2010006.0]
# A01-S018  [2010018.0]
# A01-S021  [2010021.0]
# A01-S035  [2010035.0]
# A01-S036  [2010036.0]
# ...               ...
# SPU594    [2503594.0]
# SPU596    [2503596.0]
# SPU663    [2503663.0]
# SPU673    [2503673.0]
# SPU674    [2503674.0]
#
# [936 rows x 1 columns]
#                     Modalidad RSH
# Código Sitio (TP)
# A01-S002           [TP Anfitrión]
# A01-S003           [TP Anfitrión]
# A01-S004           [TP Anfitrión]
# A01-S008           [TP Anfitrión]
# A01-S011           [TP Anfitrión]
# ...                           ...
# SI_029             [TP Anfitrión]
# SI_030               [TP Huésped]
# SI_040             [TP Anfitrión]
# SPU2279              [TP Huésped]
# SPU2280              [TP Huésped]
#
# [1061 rows x 1 columns]
#                   MOCN/MORAN
# Código Sitio (TP)
# A01-S002              [MOCN]
# A01-S003              [MOCN]
# A01-S004              [MOCN]
# A01-S008              [MOCN]
# A01-S011              [MOCN]
# ...                      ...
# SI_029               [MORAN]
# SI_030               [MORAN]
# SI_040                [MOCN]
# SPU2279              [MORAN]
# SPU2280              [MORAN]
#
# [1061 rows x 1 columns]

# %%
df = df_1.join(df_2, how='left').join(df_3, how='left').join(df_4, how='left').join(df_5, how='left')
display(df)
# Out:
#                EMG                            Nombre Tipo Estación  \
# Código
# 1_UNAGRO       NaN                         El Palmar         Macro
# 2_UNAGRO       NaN                         El Palmar         Macro
# A01-E133    XRCESE                Río IV E Sarmiento         EasyM
# A01-E134    XRCEAL                    Río IV LN Alem         EasyM
# A01-E135    XRCEMO                  Río IV E Mosconi         EasyM
# ...            ...                               ...           ...
# SPU996      XXYYZZ       AMBA BERAZATEGUI 2020 - 018         Macro
# SPU997      XXYYZZ       AMBA BERAZATEGUI 2020 - 019         Macro
# SPU998      SBB12O  Berazategui Barrio 12 de Octubre         Macro
# SPU999      XXYYZZ       AMBA BERAZATEGUI 2020 - 021         Macro
# Yacht Club  XXYYZZ                          Nordelta         Macro
#
#            Estado Sitio    Latitud   Longitud Región  E-NODEB Id G-NODEB Id  \
# Código
# 1_UNAGRO             CT -27.166490 -61.690980   LINO         NaN        NaN
# 2_UNAGRO             CT -27.199777 -61.845519   LINO         NaN        NaN
# A01-E133             OA -33.142181 -64.348739   MEDI   [10133.0]        NaN
# A01-E134             OA -33.141588 -64.338766   MEDI   [10133.0]        NaN
# A01-E135             OA -33.149821 -64.354526   MEDI   [10133.0]        NaN
# ...                 ...        ...        ...    ...         ...        ...
# SPU996               BS -34.777053 -58.259333   AMBA  [503996.0]        NaN
# SPU997               BS -34.766352 -58.238844   AMBA  [503997.0]        NaN
# SPU998               BS -34.767692 -58.229362  AMBA   [503998.0]        NaN
# SPU999               BS -34.760799 -58.222894   AMBA  [503999.0]        NaN
# Yacht Club           BS -34.385084 -58.642913   AMBA         NaN        NaN
#
#            Modalidad RSH MOCN/MORAN
# Código
# 1_UNAGRO             NaN        NaN
# 2_UNAGRO             NaN        NaN
# A01-E133             NaN        NaN
# A01-E134             NaN        NaN
# A01-E135             NaN        NaN
# ...                  ...        ...
# SPU996               NaN        NaN
# SPU997               NaN        NaN
# SPU998               NaN        NaN
# SPU999               NaN        NaN
# Yacht Club           NaN        NaN
#
# [19755 rows x 11 columns]

# %%
# Algunos ejemplos:

print(df[df.index == 'A18-S141'].to_json(force_ascii=False, indent=2, orient='records'))
print(df[df.index == 'A38-A683'].to_json(force_ascii=False, indent=2, orient='records'))
# Out:
# [
#   {
#     "EMG":"IPFFCC",
#     "Nombre":"Posadas Estacion FFCC",
#     "Tipo Estación":"Macro",
#     "Estado Sitio":"OA",
#     "Latitud":-27.422534,
#     "Longitud":-55.881409,
#     "Región":"LINO",
#     "E-NODEB Id":[
#       180141.0,
#       183141.0,
#       187141.0,
#       182141.0,
#       186141.0
#     ],
#     "G-NODEB Id":null,
#     "Modalidad RSH":null,
#     "MOCN\/MORAN":null
#   }
# ]
# [
#   {
#     "EMG":"BBBRSH",
#     "Nombre":"BBlanca Villa Bordeu RSH",
#     "Tipo Estación":"Macro",
#     "Estado Sitio":"OA",
#     "Latitud":-38.687398,
#     "Longitud":-62.341009,
#     "Región":"SUR",
#     "E-NODEB Id":[
#       900003.0
#     ],
#     "G-NODEB Id":null,
#     "Modalidad RSH":[
#       "TP Huésped"
#     ],
#     "MOCN\/MORAN":[
#       "MOCN",
#       "MORAN"
#     ]
#   }
# ]
