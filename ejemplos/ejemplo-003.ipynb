# %%
# Importación de paquetes requeridos
import os
import io
import requests
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")
import numpy as np

from IPython.display import display, Markdown, Latex

import json

# %%
import matplotlib.pylab as pylab
params = {
    'legend.fontsize': 'x-large',
    'axes.labelsize': 'x-large',
    'axes.titlesize':'x-large',
    'xtick.labelsize':'x-large',
    'ytick.labelsize':'x-large',
    'lines.linewidth' : 3,
}
pylab.rcParams.update(params)

# %%
# Función auxiliar para visualizar los datos
def pp(obj):
    print(json.dumps(obj, indent=2))

# %%
# La operación queda con la forma siguiente:
# «para cada fila r, convertir el valor de la columna "col" en un tipo numérico (pd.to_numeric),
# ignorando los valores nulos (errors='coerce'), redondeando hacia abajo al entero más cercano
# (np.floor) y almacenándolo como entero de 64 bits (astype('Int64'))»

def pd_to_int(df:pd.DataFrame, col:str) -> int:
    return np.floor(pd.to_numeric(df[col], errors='coerce')).astype('Int64')

# %%
# Parmámetros
iga_api_base_url = 'http://ing-acc-movil01.personal.corp/ingenier@/symfony/public/index.php/api'

# %%
display(Markdown(f"# Ejemplo 003: Descarga del reporte de Datos Outdoor y post procesado para uso del área de STEM"))
# Out:
# # Ejemplo 003: Descarga del reporte de Datos Outdoor y post procesado para uso del área de STEM

# %%
# Llamamos a un endpoint de prueba en la API de IGA para verificar conectividad
display(Markdown("### IGA API test"))
x = requests.get(iga_api_base_url + '/public/db-sync-state')
pp(x.json())
# Out:
# ### IGA API test
# {
#   "status": "success",
#   "data": {
#     "Uid": "41337",
#     "State": "DB_SYNC_STATE_IDLE",
#     "LastSyncTimestamp": "01-06-2022 11:14:05",
#     "SyncState": "OK",
#     "ProjectsUpdated": "DataManager, AMBA, LINO"
#   }
# }

# %%
# Llamamos al endpoint generic-report para obtener el reporte de datos outdoor de los sitios operativos:

# Parámetros en el payload de la request con que llamamos al endpoint de IGA:
payload = {
    # Nombre del reporte: datos_outdoor
    "reportName": "datos_outdoor",
    # Sitios seleccionados: ninguno
    "siteNames": [],
    # Parámetros de filtrado: todos los sitios en estado operativo (OA).
    # Son los sitios que tienen al menos una celda operativa.
    "filteringParams": { "SiteVisualizationData.SiteStatus": ["OA"] },
    # Seleccionar por nombres de sitio: no
    "selectBySiteNames": False,
    # Seleccionar por parámetros de filtrado: sí
    "selectByFilteringParams": True
}
# Obtenemos los datos. Este proceso puede tardar algunos minutos.
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)

# En x almacenamos los datos devueltos por el endpoint de IGA.
# Es un archivo xlsx en formato binario

# Usando pandas, con la función read_excel, leemos los datos y los almacenamos
# en memoria como un objeto de python:
with io.BytesIO(x.content) as fh:
    df_raw = pd.read_excel(fh)

# %%
# Visualizamos los datos obtenidos:
display(Markdown(f"# Datos Outdoor - Sitios: SiteStatus = OA"))
display(Markdown(f"### Tabla con orientación normal:"))
display(df_raw)

display(Markdown(f"### Tabla transpuesta:"))
# Los mismos datos pero transponiéndolos (intercambiando filas por columnas) para poder ver mejor todos los nombres de columnas:
display(df_raw.transpose())
# Out:
# # Datos Outdoor - Sitios: SiteStatus = OA
# ### Tabla con orientación normal:
#        Proyecto    Código     Sector            Portadora        Estado  \
# 0          MEDI  A01-E133  XRCESEL1G     LTE FDD_AWS_2225     Operativo
# 1          MEDI  A01-E133  XRCESEL1H     LTE FDD_AWS_2225     Operativo
# 2          MEDI  A01-E133  XRCESEL1I     LTE FDD_AWS_2225     Operativo
# 3          MEDI  A01-E133  XRCESEM1G  LTE FDD_1900MHz_975  No Operativo
# 4          MEDI  A01-E133  XRCESEM1H  LTE FDD_1900MHz_975  No Operativo
# ...         ...       ...        ...                  ...           ...
# 175846     AMBA    SPU990  SBBORIU12       WCDMA1900_9788     Operativo
# 175847     AMBA    SPU990  SBBORIU13       WCDMA1900_9788     Operativo
# 175848     AMBA    SPU990  SBBORIV21        WCDMA850_4358     Operativo
# 175849     AMBA    SPU990  SBBORIV22        WCDMA850_4358     Operativo
# 175850     AMBA    SPU990  SBBORIV23        WCDMA850_4358     Operativo
#
#         Latitud Antena  Longitud Antena  Id Antena    Modelo Antena  \
# 0           -33.142181       -64.348739          1          AAU3940
# 1           -33.142181       -64.348739          2          AAU3940
# 2           -33.142181       -64.348739          3          AAU3940
# 3           -33.142181       -64.348739          1          AAU3940
# 4           -33.142181       -64.348739          2          AAU3940
# ...                ...              ...        ...              ...
# 175846      -34.790932       -58.239595          2  DBXDH-6565A-VTM
# 175847      -34.790932       -58.239595          3  DBXDH-6565A-VTM
# 175848      -34.790932       -58.239595          1  DBXDH-6565A-VTM
# 175849      -34.790932       -58.239595          2  DBXDH-6565A-VTM
# 175850      -34.790932       -58.239595          3  DBXDH-6565A-VTM
#
#         Id Puerto  ... Altura Antena Azimuth Físico Azimuth Efectivo  \
# 0               1  ...          12.0           40.0             39.0
# 1               1  ...          12.0          160.0            159.0
# 2               1  ...          12.0          280.0            279.0
# 3               1  ...          12.0           40.0             39.0
# 4               1  ...          12.0          160.0            159.0
# ...           ...  ...           ...            ...              ...
# 175846          3  ...          21.0          180.0            180.0
# 175847          3  ...          21.0          300.0            300.0
# 175848          1  ...          21.0           60.0             60.0
# 175849          1  ...          21.0          180.0            180.0
# 175850          1  ...          21.0          300.0            300.0
#
#        Tilt Mec.  Tilt Eléc.  Twist  Ancho Horiz.  Ancho Vert.  Ganancia dBi  \
# 0           -0.0         2.0    0.0            73           12     13.972812
# 1           -0.0         2.0    0.0            73           12     13.972812
# 2           -0.0         2.0    0.0            73           12     13.972812
# 3           -0.0         2.0    0.0            73           12     13.972812
# 4           -0.0         2.0    0.0            73           12     13.972812
# ...          ...         ...    ...           ...          ...           ...
# 175846      -0.0         2.0    0.0            64           10     15.331015
# 175847      -0.0        10.0    0.0            64           10     15.331015
# 175848      -0.0         4.0    0.0            64           10     15.331015
# 175849      -0.0         4.0    0.0            64           10     15.331015
# 175850      -0.0         4.0    0.0            64           10     15.331015
#
#         Cota de Terreno
# 0                436.86
# 1                436.86
# 2                436.86
# 3                436.86
# 4                436.86
# ...                 ...
# 175846            18.77
# 175847            18.77
# 175848            18.77
# 175849            18.77
# 175850            18.77
#
# [175851 rows x 26 columns]
# ### Tabla transpuesta:
#                                0                 1                 2       \
# Proyecto                         MEDI              MEDI              MEDI
# Código                       A01-E133          A01-E133          A01-E133
# Sector                      XRCESEL1G         XRCESEL1H         XRCESEL1I
# Portadora            LTE FDD_AWS_2225  LTE FDD_AWS_2225  LTE FDD_AWS_2225
# Estado                      Operativo         Operativo         Operativo
# Latitud Antena             -33.142181        -33.142181        -33.142181
# Longitud Antena            -64.348739        -64.348739        -64.348739
# Id Antena                           1                 2                 3
# Modelo Antena                 AAU3940           AAU3940           AAU3940
# Id Puerto                           1                 1                 1
# Id Puertos Uplink                 1,2               1,2               1,2
# Id Puertos Downlink               1,2               1,2               1,2
# Config. Puertos                 2Rx2T             2Rx2T             2Rx2T
# Controlador Eléc         Controller 1      Controller 1      Controller 1
# Frec. Mín.                       1710              1710              1710
# Frec. Máx.                       2170              2170              2170
# Altura Antena                    12.0              12.0              12.0
# Azimuth Físico                   40.0             160.0             280.0
# Azimuth Efectivo                 39.0             159.0             279.0
# Tilt Mec.                        -0.0              -0.0              -0.0
# Tilt Eléc.                        2.0               2.0               2.0
# Twist                             0.0               0.0               0.0
# Ancho Horiz.                       73                73                73
# Ancho Vert.                        12                12                12
# Ganancia dBi                13.972812         13.972812         13.972812
# Cota de Terreno                436.86            436.86            436.86
#
#                                   3                    4       \
# Proyecto                            MEDI                 MEDI
# Código                          A01-E133             A01-E133
# Sector                         XRCESEM1G            XRCESEM1H
# Portadora            LTE FDD_1900MHz_975  LTE FDD_1900MHz_975
# Estado                      No Operativo         No Operativo
# Latitud Antena                -33.142181           -33.142181
# Longitud Antena               -64.348739           -64.348739
# Id Antena                              1                    2
# Modelo Antena                    AAU3940              AAU3940
# Id Puerto                              1                    1
# Id Puertos Uplink                    1,2                  1,2
# Id Puertos Downlink                  1,2                  1,2
# Config. Puertos                    2Rx2T                2Rx2T
# Controlador Eléc            Controller 1         Controller 1
# Frec. Mín.                          1710                 1710
# Frec. Máx.                          2170                 2170
# Altura Antena                       12.0                 12.0
# Azimuth Físico                      40.0                160.0
# Azimuth Efectivo                    39.0                159.0
# Tilt Mec.                           -0.0                 -0.0
# Tilt Eléc.                           2.0                  2.0
# Twist                                0.0                  0.0
# Ancho Horiz.                          73                   73
# Ancho Vert.                           12                   12
# Ganancia dBi                   13.972812            13.972812
# Cota de Terreno                   436.86               436.86
#
#                                   5               6               7       \
# Proyecto                            MEDI            MEDI            MEDI
# Código                          A01-E133        A01-E133        A01-E133
# Sector                         XRCESEM1I       XRCESEU1G       XRCESEU1H
# Portadora            LTE FDD_1900MHz_975  WCDMA1900_9813  WCDMA1900_9813
# Estado                      No Operativo       Operativo       Operativo
# Latitud Antena                -33.142181      -33.142181      -33.142181
# Longitud Antena               -64.348739      -64.348739      -64.348739
# Id Antena                              3               1               2
# Modelo Antena                    AAU3940         AAU3940         AAU3940
# Id Puerto                              1               1               1
# Id Puertos Uplink                    1,2             1,2             1,2
# Id Puertos Downlink                  1,2             1,2             1,2
# Config. Puertos                    2Rx2T           2Rx2T           2Rx2T
# Controlador Eléc            Controller 1    Controller 1    Controller 1
# Frec. Mín.                          1710            1710            1710
# Frec. Máx.                          2170            2170            2170
# Altura Antena                       12.0            12.0            12.0
# Azimuth Físico                     280.0            40.0           160.0
# Azimuth Efectivo                   279.0            39.0           159.0
# Tilt Mec.                           -0.0            -0.0            -0.0
# Tilt Eléc.                           2.0             2.0             2.0
# Twist                                0.0             0.0             0.0
# Ancho Horiz.                          73              73              73
# Ancho Vert.                           12              12              12
# Ganancia dBi                   13.972812       13.972812       13.972812
# Cota de Terreno                   436.86          436.86          436.86
#
#                              8                 9       ...  \
# Proyecto                       MEDI              MEDI  ...
# Código                     A01-E133          A01-E134  ...
# Sector                    XRCESEU1I         XRCEALL1G  ...
# Portadora            WCDMA1900_9813  LTE FDD_AWS_2225  ...
# Estado                    Operativo         Operativo  ...
# Latitud Antena           -33.142181        -33.141588  ...
# Longitud Antena          -64.348739        -64.338766  ...
# Id Antena                         3                 1  ...
# Modelo Antena               AAU3940           AAU3940  ...
# Id Puerto                         1                 1  ...
# Id Puertos Uplink               1,2               1,2  ...
# Id Puertos Downlink             1,2               1,2  ...
# Config. Puertos               2Rx2T             2Rx2T  ...
# Controlador Eléc       Controller 1      Controller 1  ...
# Frec. Mín.                     1710              1710  ...
# Frec. Máx.                     2170              2170  ...
# Altura Antena                  12.0              12.0  ...
# Azimuth Físico                280.0              40.0  ...
# Azimuth Efectivo              279.0              39.0  ...
# Tilt Mec.                      -0.0              -0.0  ...
# Tilt Eléc.                      2.0               2.0  ...
# Twist                           0.0               0.0  ...
# Ancho Horiz.                     73                73  ...
# Ancho Vert.                      12                12  ...
# Ganancia dBi              13.972812         13.972812  ...
# Cota de Terreno              436.86            435.85  ...
#
#                                   175841               175842  \
# Proyecto                            AMBA                 AMBA
# Código                            SPU990               SPU990
# Sector                         SBBORIN13            SBBORIO11
# Portadora            LTE FDD_700MHz_9360  LTE FDD_850MHz_2474
# Estado                         Operativo            Operativo
# Latitud Antena                -34.790932           -34.790932
# Longitud Antena               -58.239595           -58.239595
# Id Antena                              6                    1
# Modelo Antena                 ATR4518R13      DBXDH-6565A-VTM
# Id Puerto                              3                    1
# Id Puertos Uplink                    3,4                  1,2
# Id Puertos Downlink                  3,4                  1,2
# Config. Puertos                    2Rx2T                2Rx2T
# Controlador Eléc     Port 3-4 690-960Mhz             Port 1-2
# Frec. Mín.                           690                  806
# Frec. Máx.                           960                 2180
# Altura Antena                       21.0                 21.0
# Azimuth Físico                     300.0                 60.0
# Azimuth Efectivo                   300.0                 60.0
# Tilt Mec.                           -0.0                 -0.0
# Tilt Eléc.                          10.0                  4.0
# Twist                                0.0                  0.0
# Ancho Horiz.                          65                   64
# Ancho Vert.                           13                   10
# Ganancia dBi                       14.22            15.331015
# Cota de Terreno                    18.77                18.77
#
#                                   175843               175844  \
# Proyecto                            AMBA                 AMBA
# Código                            SPU990               SPU990
# Sector                         SBBORIO12            SBBORIO13
# Portadora            LTE FDD_850MHz_2474  LTE FDD_850MHz_2474
# Estado                         Operativo            Operativo
# Latitud Antena                -34.790932           -34.790932
# Longitud Antena               -58.239595           -58.239595
# Id Antena                              2                    3
# Modelo Antena            DBXDH-6565A-VTM      DBXDH-6565A-VTM
# Id Puerto                              1                    1
# Id Puertos Uplink                    1,2                  1,2
# Id Puertos Downlink                  1,2                  1,2
# Config. Puertos                    2Rx2T                2Rx2T
# Controlador Eléc                Port 1-2             Port 1-2
# Frec. Mín.                           806                  806
# Frec. Máx.                          2180                 2180
# Altura Antena                       21.0                 21.0
# Azimuth Físico                     180.0                300.0
# Azimuth Efectivo                   180.0                300.0
# Tilt Mec.                           -0.0                 -0.0
# Tilt Eléc.                           4.0                  4.0
# Twist                                0.0                  0.0
# Ancho Horiz.                          64                   64
# Ancho Vert.                           10                   10
# Ganancia dBi                   15.331015            15.331015
# Cota de Terreno                    18.77                18.77
#
#                               175845           175846           175847  \
# Proyecto                        AMBA             AMBA             AMBA
# Código                        SPU990           SPU990           SPU990
# Sector                     SBBORIU11        SBBORIU12        SBBORIU13
# Portadora             WCDMA1900_9788   WCDMA1900_9788   WCDMA1900_9788
# Estado                     Operativo        Operativo        Operativo
# Latitud Antena            -34.790932       -34.790932       -34.790932
# Longitud Antena           -58.239595       -58.239595       -58.239595
# Id Antena                          1                2                3
# Modelo Antena        DBXDH-6565A-VTM  DBXDH-6565A-VTM  DBXDH-6565A-VTM
# Id Puerto                          3                3                3
# Id Puertos Uplink                3,4              3,4              3,4
# Id Puertos Downlink              3,4              3,4              3,4
# Config. Puertos                2Rx2T            2Rx2T            2Rx2T
# Controlador Eléc            Port 3-4         Port 3-4         Port 3-4
# Frec. Mín.                       806              806              806
# Frec. Máx.                      2180             2180             2180
# Altura Antena                   21.0             21.0             21.0
# Azimuth Físico                  60.0            180.0            300.0
# Azimuth Efectivo                60.0            180.0            300.0
# Tilt Mec.                       -0.0             -0.0             -0.0
# Tilt Eléc.                       3.0              2.0             10.0
# Twist                            0.0              0.0              0.0
# Ancho Horiz.                      64               64               64
# Ancho Vert.                       10               10               10
# Ganancia dBi               15.331015        15.331015        15.331015
# Cota de Terreno                18.77            18.77            18.77
#
#                               175848           175849           175850
# Proyecto                        AMBA             AMBA             AMBA
# Código                        SPU990           SPU990           SPU990
# Sector                     SBBORIV21        SBBORIV22        SBBORIV23
# Portadora              WCDMA850_4358    WCDMA850_4358    WCDMA850_4358
# Estado                     Operativo        Operativo        Operativo
# Latitud Antena            -34.790932       -34.790932       -34.790932
# Longitud Antena           -58.239595       -58.239595       -58.239595
# Id Antena                          1                2                3
# Modelo Antena        DBXDH-6565A-VTM  DBXDH-6565A-VTM  DBXDH-6565A-VTM
# Id Puerto                          1                1                1
# Id Puertos Uplink                1,2              1,2              1,2
# Id Puertos Downlink              1,2              1,2              1,2
# Config. Puertos                2Rx2T            2Rx2T            2Rx2T
# Controlador Eléc            Port 1-2         Port 1-2         Port 1-2
# Frec. Mín.                       806              806              806
# Frec. Máx.                      2180             2180             2180
# Altura Antena                   21.0             21.0             21.0
# Azimuth Físico                  60.0            180.0            300.0
# Azimuth Efectivo                60.0            180.0            300.0
# Tilt Mec.                       -0.0             -0.0             -0.0
# Tilt Eléc.                       4.0              4.0              4.0
# Twist                            0.0              0.0              0.0
# Ancho Horiz.                      64               64               64
# Ancho Vert.                       10               10               10
# Ganancia dBi               15.331015        15.331015        15.331015
# Cota de Terreno                18.77            18.77            18.77
#
# [26 rows x 175851 columns]

# %%
# Primero filtramos por la columna 'Estado' para quedarnos únicamente con las celdas operativas:
df = df_raw.loc[df_raw['Estado'] == 'Operativo'].copy()

# Agregamos las columnas config_puertos_r y config_puertos_t, que almacenan la cantidad de puertos de
# Uplink y Downlink respectivamente. Para eso, usamos la función apply que obtiene para cada fila el
# valor de la nueva columna como una función de los demás valores de la fila.
# Por ejemplo, para el caso de config_puertos_r, tomamos la columna 'Id Puertos Uplink' que contiene
# los id de puertos separados por coma.
# Separamos los id usando la función split y el separador ',', con lo que convertimos el texto en un
# array con todos los elementos.
# Por último, almacenamos en la nueva columna la cantidad de elementos del array usando la función len:
df['config_puertos_r'] = df.apply(lambda r: len(r['Id Puertos Uplink'].split(',')), axis=1)
df['config_puertos_t'] = df.apply(lambda r: len(r['Id Puertos Downlink'].split(',')), axis=1)

# Algunos campos deben ser convertidos a enteros. Aplicamos un método similar al anterior, pero
# esta vez usamos una función definida anteriormente pd_to_int, que convierte el número en entero,
# o None (en python None significa valor vacío) en caso de estar vacío (Ej. el tilt eléctrico es
# nulo en celdas que no tienen ningún controlador eléctrico asignado)

df['Azimuth Efectivo'] = pd_to_int(df, 'Azimuth Efectivo')
df['Tilt Mec.'] = pd_to_int(df, 'Tilt Mec.')
df['Tilt Eléc.'] = pd_to_int(df, 'Tilt Eléc.')
df['Ancho Horiz.'] = pd_to_int(df, 'Ancho Horiz.')
df['Ancho Vert.'] = pd_to_int(df, 'Ancho Vert.')

display(df.transpose())
# Out:
#                                0                 1                 2       \
# Proyecto                         MEDI              MEDI              MEDI
# Código                       A01-E133          A01-E133          A01-E133
# Sector                      XRCESEL1G         XRCESEL1H         XRCESEL1I
# Portadora            LTE FDD_AWS_2225  LTE FDD_AWS_2225  LTE FDD_AWS_2225
# Estado                      Operativo         Operativo         Operativo
# Latitud Antena             -33.142181        -33.142181        -33.142181
# Longitud Antena            -64.348739        -64.348739        -64.348739
# Id Antena                           1                 2                 3
# Modelo Antena                 AAU3940           AAU3940           AAU3940
# Id Puerto                           1                 1                 1
# Id Puertos Uplink                 1,2               1,2               1,2
# Id Puertos Downlink               1,2               1,2               1,2
# Config. Puertos                 2Rx2T             2Rx2T             2Rx2T
# Controlador Eléc         Controller 1      Controller 1      Controller 1
# Frec. Mín.                       1710              1710              1710
# Frec. Máx.                       2170              2170              2170
# Altura Antena                    12.0              12.0              12.0
# Azimuth Físico                   40.0             160.0             280.0
# Azimuth Efectivo                   39               159               279
# Tilt Mec.                           0                 0                 0
# Tilt Eléc.                          2                 2                 2
# Twist                             0.0               0.0               0.0
# Ancho Horiz.                       73                73                73
# Ancho Vert.                        12                12                12
# Ganancia dBi                13.972812         13.972812         13.972812
# Cota de Terreno                436.86            436.86            436.86
# config_puertos_r                    2                 2                 2
# config_puertos_t                    2                 2                 2
#
#                              6               7               8       \
# Proyecto                       MEDI            MEDI            MEDI
# Código                     A01-E133        A01-E133        A01-E133
# Sector                    XRCESEU1G       XRCESEU1H       XRCESEU1I
# Portadora            WCDMA1900_9813  WCDMA1900_9813  WCDMA1900_9813
# Estado                    Operativo       Operativo       Operativo
# Latitud Antena           -33.142181      -33.142181      -33.142181
# Longitud Antena          -64.348739      -64.348739      -64.348739
# Id Antena                         1               2               3
# Modelo Antena               AAU3940         AAU3940         AAU3940
# Id Puerto                         1               1               1
# Id Puertos Uplink               1,2             1,2             1,2
# Id Puertos Downlink             1,2             1,2             1,2
# Config. Puertos               2Rx2T           2Rx2T           2Rx2T
# Controlador Eléc       Controller 1    Controller 1    Controller 1
# Frec. Mín.                     1710            1710            1710
# Frec. Máx.                     2170            2170            2170
# Altura Antena                  12.0            12.0            12.0
# Azimuth Físico                 40.0           160.0           280.0
# Azimuth Efectivo                 39             159             279
# Tilt Mec.                         0               0               0
# Tilt Eléc.                        2               2               2
# Twist                           0.0             0.0             0.0
# Ancho Horiz.                     73              73              73
# Ancho Vert.                      12              12              12
# Ganancia dBi              13.972812       13.972812       13.972812
# Cota de Terreno              436.86          436.86          436.86
# config_puertos_r                  2               2               2
# config_puertos_t                  2               2               2
#
#                                9                 10                11      \
# Proyecto                         MEDI              MEDI              MEDI
# Código                       A01-E134          A01-E134          A01-E134
# Sector                      XRCEALL1G         XRCEALL1H         XRCEALL1I
# Portadora            LTE FDD_AWS_2225  LTE FDD_AWS_2225  LTE FDD_AWS_2225
# Estado                      Operativo         Operativo         Operativo
# Latitud Antena             -33.141588        -33.141588        -33.141588
# Longitud Antena            -64.338766        -64.338766        -64.338766
# Id Antena                           1                 2                 3
# Modelo Antena                 AAU3940           AAU3940           AAU3940
# Id Puerto                           1                 1                 1
# Id Puertos Uplink                 1,2               1,2               1,2
# Id Puertos Downlink               1,2               1,2               1,2
# Config. Puertos                 2Rx2T             2Rx2T             2Rx2T
# Controlador Eléc         Controller 1      Controller 1      Controller 1
# Frec. Mín.                       1710              1710              1710
# Frec. Máx.                       2170              2170              2170
# Altura Antena                    12.0              12.0              12.0
# Azimuth Físico                   40.0             160.0             280.0
# Azimuth Efectivo                   39               159               279
# Tilt Mec.                           0                 0                 0
# Tilt Eléc.                          2                 2                 2
# Twist                             0.0               0.0               0.0
# Ancho Horiz.                       73                73                73
# Ancho Vert.                        12                12                12
# Ganancia dBi                13.972812         13.972812         13.972812
# Cota de Terreno                435.85            435.85            435.85
# config_puertos_r                    2                 2                 2
# config_puertos_t                    2                 2                 2
#
#                              15      ...               175841  \
# Proyecto                       MEDI  ...                 AMBA
# Código                     A01-E134  ...               SPU990
# Sector                    XRCEALU1G  ...            SBBORIN13
# Portadora            WCDMA1900_9813  ...  LTE FDD_700MHz_9360
# Estado                    Operativo  ...            Operativo
# Latitud Antena           -33.141588  ...           -34.790932
# Longitud Antena          -64.338766  ...           -58.239595
# Id Antena                         1  ...                    6
# Modelo Antena               AAU3940  ...           ATR4518R13
# Id Puerto                         1  ...                    3
# Id Puertos Uplink               1,2  ...                  3,4
# Id Puertos Downlink             1,2  ...                  3,4
# Config. Puertos               2Rx2T  ...                2Rx2T
# Controlador Eléc       Controller 1  ...  Port 3-4 690-960Mhz
# Frec. Mín.                     1710  ...                  690
# Frec. Máx.                     2170  ...                  960
# Altura Antena                  12.0  ...                 21.0
# Azimuth Físico                 40.0  ...                300.0
# Azimuth Efectivo                 39  ...                  300
# Tilt Mec.                         0  ...                    0
# Tilt Eléc.                        2  ...                   10
# Twist                           0.0  ...                  0.0
# Ancho Horiz.                     73  ...                   65
# Ancho Vert.                      12  ...                   13
# Ganancia dBi              13.972812  ...                14.22
# Cota de Terreno              435.85  ...                18.77
# config_puertos_r                  2  ...                    2
# config_puertos_t                  2  ...                    2
#
#                                   175842               175843  \
# Proyecto                            AMBA                 AMBA
# Código                            SPU990               SPU990
# Sector                         SBBORIO11            SBBORIO12
# Portadora            LTE FDD_850MHz_2474  LTE FDD_850MHz_2474
# Estado                         Operativo            Operativo
# Latitud Antena                -34.790932           -34.790932
# Longitud Antena               -58.239595           -58.239595
# Id Antena                              1                    2
# Modelo Antena            DBXDH-6565A-VTM      DBXDH-6565A-VTM
# Id Puerto                              1                    1
# Id Puertos Uplink                    1,2                  1,2
# Id Puertos Downlink                  1,2                  1,2
# Config. Puertos                    2Rx2T                2Rx2T
# Controlador Eléc                Port 1-2             Port 1-2
# Frec. Mín.                           806                  806
# Frec. Máx.                          2180                 2180
# Altura Antena                       21.0                 21.0
# Azimuth Físico                      60.0                180.0
# Azimuth Efectivo                      60                  180
# Tilt Mec.                              0                    0
# Tilt Eléc.                             4                    4
# Twist                                0.0                  0.0
# Ancho Horiz.                          64                   64
# Ancho Vert.                           10                   10
# Ganancia dBi                   15.331015            15.331015
# Cota de Terreno                    18.77                18.77
# config_puertos_r                       2                    2
# config_puertos_t                       2                    2
#
#                                   175844           175845           175846  \
# Proyecto                            AMBA             AMBA             AMBA
# Código                            SPU990           SPU990           SPU990
# Sector                         SBBORIO13        SBBORIU11        SBBORIU12
# Portadora            LTE FDD_850MHz_2474   WCDMA1900_9788   WCDMA1900_9788
# Estado                         Operativo        Operativo        Operativo
# Latitud Antena                -34.790932       -34.790932       -34.790932
# Longitud Antena               -58.239595       -58.239595       -58.239595
# Id Antena                              3                1                2
# Modelo Antena            DBXDH-6565A-VTM  DBXDH-6565A-VTM  DBXDH-6565A-VTM
# Id Puerto                              1                3                3
# Id Puertos Uplink                    1,2              3,4              3,4
# Id Puertos Downlink                  1,2              3,4              3,4
# Config. Puertos                    2Rx2T            2Rx2T            2Rx2T
# Controlador Eléc                Port 1-2         Port 3-4         Port 3-4
# Frec. Mín.                           806              806              806
# Frec. Máx.                          2180             2180             2180
# Altura Antena                       21.0             21.0             21.0
# Azimuth Físico                     300.0             60.0            180.0
# Azimuth Efectivo                     300               60              180
# Tilt Mec.                              0                0                0
# Tilt Eléc.                             4                3                2
# Twist                                0.0              0.0              0.0
# Ancho Horiz.                          64               64               64
# Ancho Vert.                           10               10               10
# Ganancia dBi                   15.331015        15.331015        15.331015
# Cota de Terreno                    18.77            18.77            18.77
# config_puertos_r                       2                2                2
# config_puertos_t                       2                2                2
#
#                               175847           175848           175849  \
# Proyecto                        AMBA             AMBA             AMBA
# Código                        SPU990           SPU990           SPU990
# Sector                     SBBORIU13        SBBORIV21        SBBORIV22
# Portadora             WCDMA1900_9788    WCDMA850_4358    WCDMA850_4358
# Estado                     Operativo        Operativo        Operativo
# Latitud Antena            -34.790932       -34.790932       -34.790932
# Longitud Antena           -58.239595       -58.239595       -58.239595
# Id Antena                          3                1                2
# Modelo Antena        DBXDH-6565A-VTM  DBXDH-6565A-VTM  DBXDH-6565A-VTM
# Id Puerto                          3                1                1
# Id Puertos Uplink                3,4              1,2              1,2
# Id Puertos Downlink              3,4              1,2              1,2
# Config. Puertos                2Rx2T            2Rx2T            2Rx2T
# Controlador Eléc            Port 3-4         Port 1-2         Port 1-2
# Frec. Mín.                       806              806              806
# Frec. Máx.                      2180             2180             2180
# Altura Antena                   21.0             21.0             21.0
# Azimuth Físico                 300.0             60.0            180.0
# Azimuth Efectivo                 300               60              180
# Tilt Mec.                          0                0                0
# Tilt Eléc.                        10                4                4
# Twist                            0.0              0.0              0.0
# Ancho Horiz.                      64               64               64
# Ancho Vert.                       10               10               10
# Ganancia dBi               15.331015        15.331015        15.331015
# Cota de Terreno                18.77            18.77            18.77
# config_puertos_r                   2                2                2
# config_puertos_t                   2                2                2
#
#                               175850
# Proyecto                        AMBA
# Código                        SPU990
# Sector                     SBBORIV23
# Portadora              WCDMA850_4358
# Estado                     Operativo
# Latitud Antena            -34.790932
# Longitud Antena           -58.239595
# Id Antena                          3
# Modelo Antena        DBXDH-6565A-VTM
# Id Puerto                          1
# Id Puertos Uplink                1,2
# Id Puertos Downlink              1,2
# Config. Puertos                2Rx2T
# Controlador Eléc            Port 1-2
# Frec. Mín.                       806
# Frec. Máx.                      2180
# Altura Antena                   21.0
# Azimuth Físico                 300.0
# Azimuth Efectivo                 300
# Tilt Mec.                          0
# Tilt Eléc.                         4
# Twist                            0.0
# Ancho Horiz.                      64
# Ancho Vert.                       10
# Ganancia dBi               15.331015
# Cota de Terreno                18.77
# config_puertos_r                   2
# config_puertos_t                   2
#
# [28 rows x 152185 columns]

# %%
# Finalmente creamos otro DataFrame seleccionando las columnas que nos interesan
# y renombrando los encabezados
df2 = df[[
    'Sector',
    'Latitud Antena',
    'Longitud Antena',
    'Azimuth Efectivo',
    'Tilt Mec.',
    'Tilt Eléc.',
    'Ancho Horiz.',
    'Ancho Vert.',
    'Ganancia dBi',
    'Cota de Terreno',
    'config_puertos_r',
    'config_puertos_t',
]]
df2.columns=[
    'celda',
    'latitud',
    'longitud',
    'azimuth_efvo',
    'tilt_mec',
    'tilt_elec',
    'ancho_horiz',
    'ancho_vert',
    'ganancia_dbi',
    'cota_terreno',
    'config_puertos_r',
    'config_puertos_t',
]
display(df2)
# Out:
#             celda    latitud   longitud  azimuth_efvo  tilt_mec  tilt_elec  \
# 0       XRCESEL1G -33.142181 -64.348739            39         0          2
# 1       XRCESEL1H -33.142181 -64.348739           159         0          2
# 2       XRCESEL1I -33.142181 -64.348739           279         0          2
# 6       XRCESEU1G -33.142181 -64.348739            39         0          2
# 7       XRCESEU1H -33.142181 -64.348739           159         0          2
# ...           ...        ...        ...           ...       ...        ...
# 175846  SBBORIU12 -34.790932 -58.239595           180         0          2
# 175847  SBBORIU13 -34.790932 -58.239595           300         0         10
# 175848  SBBORIV21 -34.790932 -58.239595            60         0          4
# 175849  SBBORIV22 -34.790932 -58.239595           180         0          4
# 175850  SBBORIV23 -34.790932 -58.239595           300         0          4
#
#         ancho_horiz  ancho_vert  ganancia_dbi  cota_terreno  config_puertos_r  \
# 0                73          12     13.972812        436.86                 2
# 1                73          12     13.972812        436.86                 2
# 2                73          12     13.972812        436.86                 2
# 6                73          12     13.972812        436.86                 2
# 7                73          12     13.972812        436.86                 2
# ...             ...         ...           ...           ...               ...
# 175846           64          10     15.331015         18.77                 2
# 175847           64          10     15.331015         18.77                 2
# 175848           64          10     15.331015         18.77                 2
# 175849           64          10     15.331015         18.77                 2
# 175850           64          10     15.331015         18.77                 2
#
#         config_puertos_t
# 0                      2
# 1                      2
# 2                      2
# 6                      2
# 7                      2
# ...                  ...
# 175846                 2
# 175847                 2
# 175848                 2
# 175849                 2
# 175850                 2
#
# [152185 rows x 12 columns]

# %%
# Creamos la carpeta 'output' si no existe
os.makedirs('output', exist_ok=True)

# Exportamos los datos como .csv
df2.to_csv('output/ejemplo-003.csv', index=False)
