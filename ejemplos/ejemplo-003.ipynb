# %%
# Importación de paquetes requeridos
import warnings

import io
import requests
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
plt.close("all")
import scipy
import numpy as np

from IPython.display import display, Markdown, Latex

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import dateparser
import json

# %%
# Función auxiliar para visualizar los datos
def pp(obj):
    print(json.dumps(obj, indent=2))

# %%
# Parmámetros
iga_api_base_url = 'http://ing-acc-movil01/ingenier@/symfony/public/index.php/api'
site_names = ['A21-S038']
site_names_str = ', '.join(site_names)

# %%
display(Markdown(f"# Ejemplo 003: Descarga del reporte de Datos Outdoor y post procesado para uso del área de STEM"))
# Out:
# # Ejemplo 003: Descarga del reporte de Datos Outdoor y post procesado para uso del área de STEM

# %%
# Llamamos a un endpoint de prueba en la API de IGA para verificar conectividad
display(Markdown("### IGA API test"))
x = requests.get(iga_api_base_url + '/public/db-sync-state')
pp(x.json())
# Out:
# ### IGA API test
# {
#   "status": "success",
#   "data": {
#     "Uid": "41158",
#     "State": "DB_SYNC_STATE_UPDATING",
#     "LastSyncTimestamp": "16-05-2022 16:24:17",
#     "SyncState": "OK",
#     "ProjectsUpdated": "DataManager, Litoral Sur"
#   }
# }

# %%
# Llamamos al endpoint generic-report para obtener el reporte de datos outdoor del sitio seleccionado:

# Parámetros en el payload de la request con que llamamos al endpoint de IGA:
payload = {
    # Nombre del reporte: datos_outdoor
    "reportName": "datos_outdoor",
    # Sitios seleccionados: los códigos de sitio que están almacenados en la variable site_names
    "siteNames": site_names,
    # Parámetros de filtrado: ninguno (objeto vacío: {})
    "filteringParams": {},
    # Seleccionar por nombres de sitio: sí
    "selectBySiteNames": True,
    # Seleccionar por parámetros de filtrado: no
    "selectByFilteringParams": False
}
x = requests.post(iga_api_base_url + '/public/report/generic-report', json=payload)

# En x almacenamos los datos devueltos por el endpoint de IGA. Es un archivo xlsx en formato binario

# Usando pandas, con la función read_excel, leemos los datos y los almacenamos en memoria como un objeto de python:
with io.BytesIO(x.content) as fh:
    df = pd.read_excel(fh)

# %%
# Visualizamos los datos obtenidos:
display(Markdown(f"# Datos Outdoor - Sitios: {site_names_str}"))
display(Markdown(f"### Tabla con orientación normal:"))
display(df)

display(Markdown(f"### Tabla transpuesta:"))
# Los mismos datos pero transponiéndolos (intercambiando filas por columnas) para poder ver mejor todos los nombres de columnas:
display(df.transpose())
# Out:
# # Datos Outdoor - Sitios: A21-S038
# ### Tabla con orientación normal:
#    Proyecto    Código     Sector                   Portadora        Estado  \
# 0     NORAN  A21-S038  ACARRIB11  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 1     NORAN  A21-S038  ACARRIB12  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 2     NORAN  A21-S038  ACARRIB13  LTE FDD_700MHz_9312_NB_IoT  No Operativo
# 3     NORAN  A21-S038  ACARRIH11                      GSM850     Operativo
# 4     NORAN  A21-S038  ACARRIH12                      GSM850     Operativo
# 5     NORAN  A21-S038  ACARRIH13                      GSM850     Operativo
# 6     NORAN  A21-S038  ACARRIL11            LTE FDD_AWS_2225     Operativo
# 7     NORAN  A21-S038  ACARRIL12            LTE FDD_AWS_2225     Operativo
# 8     NORAN  A21-S038  ACARRIL13            LTE FDD_AWS_2225     Operativo
# 9     NORAN  A21-S038  ACARRIM11         LTE FDD_1900MHz_975     Operativo
# 10    NORAN  A21-S038  ACARRIM12         LTE FDD_1900MHz_975     Operativo
# 11    NORAN  A21-S038  ACARRIM13         LTE FDD_1900MHz_975     Operativo
# 12    NORAN  A21-S038  ACARRIN11         LTE FDD_700MHz_9360     Operativo
# 13    NORAN  A21-S038  ACARRIN12         LTE FDD_700MHz_9360     Operativo
# 14    NORAN  A21-S038  ACARRIN13         LTE FDD_700MHz_9360     Operativo
# 15    NORAN  A21-S038  ACARRIO11         LTE FDD_850MHz_2476     Operativo
# 16    NORAN  A21-S038  ACARRIO12         LTE FDD_850MHz_2476     Operativo
# 17    NORAN  A21-S038  ACARRIO13         LTE FDD_850MHz_2476     Operativo
# 18    NORAN  A21-S038  ACARRIV11               WCDMA850_4358     Operativo
# 19    NORAN  A21-S038  ACARRIV12               WCDMA850_4358     Operativo
# 20    NORAN  A21-S038  ACARRIV13               WCDMA850_4358     Operativo
#
#     Latitud Antena  Longitud Antena  Id Antena  Modelo Antena  Id Puerto  ...  \
# 0       -25.075616       -65.490972         31  ASI4518R37v06          1  ...
# 1       -25.075616       -65.490972         32  ASI4518R37v06          1  ...
# 2       -25.075616       -65.490972         33  ASI4518R37v06          1  ...
# 3       -25.075616       -65.490972         31  ASI4518R37v06          1  ...
# 4       -25.075616       -65.490972         32  ASI4518R37v06          1  ...
# 5       -25.075616       -65.490972         33  ASI4518R37v06          1  ...
# 6       -25.075616       -65.490972         31  ASI4518R37v06          5  ...
# 7       -25.075616       -65.490972         32  ASI4518R37v06          5  ...
# 8       -25.075616       -65.490972         33  ASI4518R37v06          5  ...
# 9       -25.075616       -65.490972         31  ASI4518R37v06          7  ...
# 10      -25.075616       -65.490972         32  ASI4518R37v06          7  ...
# 11      -25.075616       -65.490972         33  ASI4518R37v06          7  ...
# 12      -25.075616       -65.490972         31  ASI4518R37v06          1  ...
# 13      -25.075616       -65.490972         32  ASI4518R37v06          1  ...
# 14      -25.075616       -65.490972         33  ASI4518R37v06          1  ...
# 15      -25.075616       -65.490972         31  ASI4518R37v06          1  ...
# 16      -25.075616       -65.490972         32  ASI4518R37v06          1  ...
# 17      -25.075616       -65.490972         33  ASI4518R37v06          1  ...
# 18      -25.075616       -65.490972         31  ASI4518R37v06          1  ...
# 19      -25.075616       -65.490972         32  ASI4518R37v06          1  ...
# 20      -25.075616       -65.490972         33  ASI4518R37v06          1  ...
#
#    Altura Antena Azimuth Físico Azimuth Efectivo Tilt Mec.  Tilt Eléc.  Twist  \
# 0           50.0            0.0              0.0      -0.0         2.0    0.0
# 1           50.0          120.0            120.0      -0.0         2.0    0.0
# 2           50.0          240.0            240.0      -0.0         2.0    0.0
# 3           50.0            0.0              0.0      -0.0         2.0    0.0
# 4           50.0          120.0            120.0      -0.0         2.0    0.0
# 5           50.0          240.0            240.0      -0.0         2.0    0.0
# 6           50.0            0.0              1.0      -0.0         2.0    0.0
# 7           50.0          120.0            121.0      -0.0         2.0    0.0
# 8           50.0          240.0            241.0      -0.0         2.0    0.0
# 9           50.0            0.0              0.0      -0.0         2.0    0.0
# 10          50.0          120.0            120.0      -0.0         2.0    0.0
# 11          50.0          240.0            240.0      -0.0         2.0    0.0
# 12          50.0            0.0              0.0      -0.0         2.0    0.0
# 13          50.0          120.0            120.0      -0.0         2.0    0.0
# 14          50.0          240.0            240.0      -0.0         2.0    0.0
# 15          50.0            0.0              0.0      -0.0         2.0    0.0
# 16          50.0          120.0            120.0      -0.0         2.0    0.0
# 17          50.0          240.0            240.0      -0.0         2.0    0.0
# 18          50.0            0.0              0.0      -0.0         2.0    0.0
# 19          50.0          120.0            120.0      -0.0         2.0    0.0
# 20          50.0          240.0            240.0      -0.0         2.0    0.0
#
#     Ancho Horiz.  Ancho Vert.  Ganancia dBi  Cota de Terreno
# 0             66           13     13.755562          1167.83
# 1             66           13     13.755562          1167.83
# 2             66           13     13.755562          1167.83
# 3             66           13     13.755562          1167.83
# 4             66           13     13.755562          1167.83
# 5             66           13     13.755562          1167.83
# 6             68            6     16.941818          1167.83
# 7             68            6     16.941818          1167.83
# 8             68            6     16.941818          1167.83
# 9             64            5     16.847862          1167.83
# 10            64            5     16.847862          1167.83
# 11            64            5     16.847862          1167.83
# 12            66           13     13.755562          1167.83
# 13            66           13     13.755562          1167.83
# 14            66           13     13.755562          1167.83
# 15            66           13     13.755562          1167.83
# 16            66           13     13.755562          1167.83
# 17            66           13     13.755562          1167.83
# 18            66           13     13.755562          1167.83
# 19            66           13     13.755562          1167.83
# 20            66           13     13.755562          1167.83
#
# [21 rows x 26 columns]
# ### Tabla transpuesta:
#                                                       0   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB11
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                     0.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       1   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB12
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                   120.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       2   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB13
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                   240.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       3   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH11
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                     0.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       4   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH12
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                   120.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       5   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH13
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                   240.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                         6   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL11
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               31
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                5,6,11,12
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      4Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                         0.0
# Azimuth Efectivo                                       1.0
# Tilt Mec.                                             -0.0
# Tilt Eléc.                                             2.0
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
#
#                                                         7   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL12
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               32
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                5,6,11,12
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      4Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                       120.0
# Azimuth Efectivo                                     121.0
# Tilt Mec.                                             -0.0
# Tilt Eléc.                                             2.0
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
#
#                                                         8   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL13
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               33
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                      5,6
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      2Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                       240.0
# Azimuth Efectivo                                     241.0
# Tilt Mec.                                             -0.0
# Tilt Eléc.                                             2.0
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
#
#                                                          9   ...  \
# Proyecto                                              NORAN  ...
# Código                                             A21-S038  ...
# Sector                                            ACARRIM11  ...
# Portadora                               LTE FDD_1900MHz_975  ...
# Estado                                            Operativo  ...
# Latitud Antena                                   -25.075616  ...
# Longitud Antena                                  -65.490972  ...
# Id Antena                                                31  ...
# Modelo Antena                                 ASI4518R37v06  ...
# Id Puerto                                                 7  ...
# Id Puertos Uplink                                  7,8,9,10  ...
# Id Puertos Downlink                                7,8,9,10  ...
# Config. Puertos                                       4Rx4T  ...
# Controlador Eléc     Controller 4 Port7-8 1695-2690Mhz CLy2  ...
# Frec. Mín.                                             1695  ...
# Frec. Máx.                                             2690  ...
# Altura Antena                                          50.0  ...
# Azimuth Físico                                          0.0  ...
# Azimuth Efectivo                                        0.0  ...
# Tilt Mec.                                              -0.0  ...
# Tilt Eléc.                                              2.0  ...
# Twist                                                   0.0  ...
# Ancho Horiz.                                             64  ...
# Ancho Vert.                                               5  ...
# Ganancia dBi                                      16.847862  ...
# Cota de Terreno                                     1167.83  ...
#
#                                                          11  \
# Proyecto                                              NORAN
# Código                                             A21-S038
# Sector                                            ACARRIM13
# Portadora                               LTE FDD_1900MHz_975
# Estado                                            Operativo
# Latitud Antena                                   -25.075616
# Longitud Antena                                  -65.490972
# Id Antena                                                33
# Modelo Antena                                 ASI4518R37v06
# Id Puerto                                                 7
# Id Puertos Uplink                                  7,8,9,10
# Id Puertos Downlink                                7,8,9,10
# Config. Puertos                                       4Rx4T
# Controlador Eléc     Controller 4 Port7-8 1695-2690Mhz CLy2
# Frec. Mín.                                             1695
# Frec. Máx.                                             2690
# Altura Antena                                          50.0
# Azimuth Físico                                        240.0
# Azimuth Efectivo                                      240.0
# Tilt Mec.                                              -0.0
# Tilt Eléc.                                              2.0
# Twist                                                   0.0
# Ancho Horiz.                                             64
# Ancho Vert.                                               5
# Ganancia dBi                                      16.847862
# Cota de Terreno                                     1167.83
#
#                                                       12  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN11
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                     0.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       13  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN12
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                   120.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       14  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN13
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                   240.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       15  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO11
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                     0.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       16  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO12
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                   120.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       17  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO13
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                   240.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       18  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV11
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                     0.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       19  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV12
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                   120.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
#                                                       20
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV13
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                   240.0
# Tilt Mec.                                           -0.0
# Tilt Eléc.                                           2.0
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
#
# [26 rows x 21 columns]

# %%
# Agregamos las columnas config_puertos_r y config_puertos_t, que almacenan la cantidad de puertos de Uplink y Downlink respectivamente
# Para eso, usamos la función apply que obtiene para cada fila el valor de la nueva columna como una función de los demás valores de la fila
# Por ejemplo, para el caso de config_puertos_r, tomamos la columna 'Id Puertos Uplink' que contiene los id de puertos separados por coma. Separamos los id usando la función split y el separador ',', con lo que convertimos el texto en un array con todos los elementos. Por último, almacenamos en la nueva columna la cantidad de elementos del array usando la función len:
df['config_puertos_r'] = df.apply(lambda r: len(r['Id Puertos Uplink'].split(',')), axis=1)
df['config_puertos_t'] = df.apply(lambda r: len(r['Id Puertos Downlink'].split(',')), axis=1)

# Algunos campos deben ser convertidos a enteros. Aplicamos un método similar al anterior, pero esta vez usamos la función int que convierte el número en entero:
df['Azimuth Efectivo'] = df.apply(lambda r: int(r['Azimuth Efectivo']), axis=1)
df['Tilt Mec.'] = df.apply(lambda r: int(r['Tilt Mec.']), axis=1)
df['Tilt Eléc.'] = df.apply(lambda r: int(r['Tilt Eléc.']), axis=1)
df['Ancho Horiz.'] = df.apply(lambda r: int(r['Ancho Horiz.']), axis=1)
df['Ancho Vert.'] = df.apply(lambda r: int(r['Ancho Vert.']), axis=1)

display(df.transpose())
# Out:
#                                                       0   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB11
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                       0
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       2
#
#                                                       1   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB12
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                     120
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       2
#
#                                                       2   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIB13
# Portadora                     LTE FDD_700MHz_9312_NB_IoT
# Estado                                      No Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                  1,2
# Config. Puertos                                    2Rx2T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                     240
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       2
#
#                                                       3   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH11
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                       0
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
#                                                       4   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH12
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                     120
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
#                                                       5   \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIH13
# Portadora                                         GSM850
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                     240
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
#                                                         6   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL11
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               31
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                5,6,11,12
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      4Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                         0.0
# Azimuth Efectivo                                         1
# Tilt Mec.                                                0
# Tilt Eléc.                                               2
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
# config_puertos_r                                         4
# config_puertos_t                                         4
#
#                                                         7   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL12
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               32
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                5,6,11,12
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      4Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                       120.0
# Azimuth Efectivo                                       121
# Tilt Mec.                                                0
# Tilt Eléc.                                               2
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
# config_puertos_r                                         4
# config_puertos_t                                         4
#
#                                                         8   \
# Proyecto                                             NORAN
# Código                                            A21-S038
# Sector                                           ACARRIL13
# Portadora                                 LTE FDD_AWS_2225
# Estado                                           Operativo
# Latitud Antena                                  -25.075616
# Longitud Antena                                 -65.490972
# Id Antena                                               33
# Modelo Antena                                ASI4518R37v06
# Id Puerto                                                5
# Id Puertos Uplink                                      5,6
# Id Puertos Downlink                              5,6,11,12
# Config. Puertos                                      2Rx4T
# Controlador Eléc     Controller 3 Port5-6 1427-2690Mhz Ly1
# Frec. Mín.                                            1427
# Frec. Máx.                                            2690
# Altura Antena                                         50.0
# Azimuth Físico                                       240.0
# Azimuth Efectivo                                       241
# Tilt Mec.                                                0
# Tilt Eléc.                                               2
# Twist                                                  0.0
# Ancho Horiz.                                            68
# Ancho Vert.                                              6
# Ganancia dBi                                     16.941818
# Cota de Terreno                                    1167.83
# config_puertos_r                                         2
# config_puertos_t                                         4
#
#                                                          9   ...  \
# Proyecto                                              NORAN  ...
# Código                                             A21-S038  ...
# Sector                                            ACARRIM11  ...
# Portadora                               LTE FDD_1900MHz_975  ...
# Estado                                            Operativo  ...
# Latitud Antena                                   -25.075616  ...
# Longitud Antena                                  -65.490972  ...
# Id Antena                                                31  ...
# Modelo Antena                                 ASI4518R37v06  ...
# Id Puerto                                                 7  ...
# Id Puertos Uplink                                  7,8,9,10  ...
# Id Puertos Downlink                                7,8,9,10  ...
# Config. Puertos                                       4Rx4T  ...
# Controlador Eléc     Controller 4 Port7-8 1695-2690Mhz CLy2  ...
# Frec. Mín.                                             1695  ...
# Frec. Máx.                                             2690  ...
# Altura Antena                                          50.0  ...
# Azimuth Físico                                          0.0  ...
# Azimuth Efectivo                                          0  ...
# Tilt Mec.                                                 0  ...
# Tilt Eléc.                                                2  ...
# Twist                                                   0.0  ...
# Ancho Horiz.                                             64  ...
# Ancho Vert.                                               5  ...
# Ganancia dBi                                      16.847862  ...
# Cota de Terreno                                     1167.83  ...
# config_puertos_r                                          4  ...
# config_puertos_t                                          4  ...
#
#                                                          11  \
# Proyecto                                              NORAN
# Código                                             A21-S038
# Sector                                            ACARRIM13
# Portadora                               LTE FDD_1900MHz_975
# Estado                                            Operativo
# Latitud Antena                                   -25.075616
# Longitud Antena                                  -65.490972
# Id Antena                                                33
# Modelo Antena                                 ASI4518R37v06
# Id Puerto                                                 7
# Id Puertos Uplink                                  7,8,9,10
# Id Puertos Downlink                                7,8,9,10
# Config. Puertos                                       4Rx4T
# Controlador Eléc     Controller 4 Port7-8 1695-2690Mhz CLy2
# Frec. Mín.                                             1695
# Frec. Máx.                                             2690
# Altura Antena                                          50.0
# Azimuth Físico                                        240.0
# Azimuth Efectivo                                        240
# Tilt Mec.                                                 0
# Tilt Eléc.                                                2
# Twist                                                   0.0
# Ancho Horiz.                                             64
# Ancho Vert.                                               5
# Ganancia dBi                                      16.847862
# Cota de Terreno                                     1167.83
# config_puertos_r                                          4
# config_puertos_t                                          4
#
#                                                       12  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN11
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                       0
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       13  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN12
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                     120
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       14  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIN13
# Portadora                            LTE FDD_700MHz_9360
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                     240
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       15  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO11
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                       0
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       16  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO12
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                     120
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       17  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIO13
# Portadora                            LTE FDD_850MHz_2476
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                1,2,3,4
# Id Puertos Downlink                              1,2,3,4
# Config. Puertos                                    4Rx4T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                     240
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       4
# config_puertos_t                                       4
#
#                                                       18  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV11
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             31
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                       0.0
# Azimuth Efectivo                                       0
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
#                                                       19  \
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV12
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             32
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     120.0
# Azimuth Efectivo                                     120
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
#                                                       20
# Proyecto                                           NORAN
# Código                                          A21-S038
# Sector                                         ACARRIV13
# Portadora                                  WCDMA850_4358
# Estado                                         Operativo
# Latitud Antena                                -25.075616
# Longitud Antena                               -65.490972
# Id Antena                                             33
# Modelo Antena                              ASI4518R37v06
# Id Puerto                                              1
# Id Puertos Uplink                                    1,2
# Id Puertos Downlink                                    1
# Config. Puertos                                    2Rx1T
# Controlador Eléc     Controller 1 Port1-2 690-960Mhz Lr1
# Frec. Mín.                                           690
# Frec. Máx.                                           960
# Altura Antena                                       50.0
# Azimuth Físico                                     240.0
# Azimuth Efectivo                                     240
# Tilt Mec.                                              0
# Tilt Eléc.                                             2
# Twist                                                0.0
# Ancho Horiz.                                          66
# Ancho Vert.                                           13
# Ganancia dBi                                   13.755562
# Cota de Terreno                                  1167.83
# config_puertos_r                                       2
# config_puertos_t                                       1
#
# [28 rows x 21 columns]

# %%
# Finalmente creamos otro DataFrame seleccionando las columnas que nos interesan y renombrando los encabezados
df2 = df[[
    'Sector',
    'Latitud Antena',
    'Longitud Antena',
    'Azimuth Efectivo',
    'Tilt Mec.',
    'Tilt Eléc.',
    'Ancho Horiz.',
    'Ancho Vert.',
    'Ganancia dBi',
    'Cota de Terreno',
    'config_puertos_r',
    'config_puertos_t',
]]
df2.columns=[
    'celda',
    'latitud',
    'longitud',
    'azimuth_efvo',
    'tilt_mec',
    'tilt_elec',
    'ancho_horiz',
    'ancho_vert',
    'ganancia_dbi',
    'cota_terreno',
    'config_puertos_r',
    'config_puertos_t',
]
display(df2)
# Out:
#         celda    latitud   longitud  azimuth_efvo  tilt_mec  tilt_elec  \
# 0   ACARRIB11 -25.075616 -65.490972             0         0          2
# 1   ACARRIB12 -25.075616 -65.490972           120         0          2
# 2   ACARRIB13 -25.075616 -65.490972           240         0          2
# 3   ACARRIH11 -25.075616 -65.490972             0         0          2
# 4   ACARRIH12 -25.075616 -65.490972           120         0          2
# 5   ACARRIH13 -25.075616 -65.490972           240         0          2
# 6   ACARRIL11 -25.075616 -65.490972             1         0          2
# 7   ACARRIL12 -25.075616 -65.490972           121         0          2
# 8   ACARRIL13 -25.075616 -65.490972           241         0          2
# 9   ACARRIM11 -25.075616 -65.490972             0         0          2
# 10  ACARRIM12 -25.075616 -65.490972           120         0          2
# 11  ACARRIM13 -25.075616 -65.490972           240         0          2
# 12  ACARRIN11 -25.075616 -65.490972             0         0          2
# 13  ACARRIN12 -25.075616 -65.490972           120         0          2
# 14  ACARRIN13 -25.075616 -65.490972           240         0          2
# 15  ACARRIO11 -25.075616 -65.490972             0         0          2
# 16  ACARRIO12 -25.075616 -65.490972           120         0          2
# 17  ACARRIO13 -25.075616 -65.490972           240         0          2
# 18  ACARRIV11 -25.075616 -65.490972             0         0          2
# 19  ACARRIV12 -25.075616 -65.490972           120         0          2
# 20  ACARRIV13 -25.075616 -65.490972           240         0          2
#
#     ancho_horiz  ancho_vert  ganancia_dbi  cota_terreno  config_puertos_r  \
# 0            66          13     13.755562       1167.83                 2
# 1            66          13     13.755562       1167.83                 2
# 2            66          13     13.755562       1167.83                 2
# 3            66          13     13.755562       1167.83                 2
# 4            66          13     13.755562       1167.83                 2
# 5            66          13     13.755562       1167.83                 2
# 6            68           6     16.941818       1167.83                 4
# 7            68           6     16.941818       1167.83                 4
# 8            68           6     16.941818       1167.83                 2
# 9            64           5     16.847862       1167.83                 4
# 10           64           5     16.847862       1167.83                 4
# 11           64           5     16.847862       1167.83                 4
# 12           66          13     13.755562       1167.83                 4
# 13           66          13     13.755562       1167.83                 4
# 14           66          13     13.755562       1167.83                 4
# 15           66          13     13.755562       1167.83                 4
# 16           66          13     13.755562       1167.83                 4
# 17           66          13     13.755562       1167.83                 4
# 18           66          13     13.755562       1167.83                 2
# 19           66          13     13.755562       1167.83                 2
# 20           66          13     13.755562       1167.83                 2
#
#     config_puertos_t
# 0                  2
# 1                  2
# 2                  2
# 3                  1
# 4                  1
# 5                  1
# 6                  4
# 7                  4
# 8                  4
# 9                  4
# 10                 4
# 11                 4
# 12                 4
# 13                 4
# 14                 4
# 15                 4
# 16                 4
# 17                 4
# 18                 1
# 19                 1
# 20                 1

# %%
# Exportamos los datos como .csv
df2.to_csv('output/ejemplo-003.csv', index=False)
